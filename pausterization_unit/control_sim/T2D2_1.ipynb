# %%
import sys
from pathlib import Path
from typing import Tuple

import joblib
import numpy as np
from numpy.linalg import inv
import matplotlib.pyplot as plt
import time
import os
from tqdm import tqdm

# Optional deps used in helper/model stack
import torch  # noqa: F401
import cvxpy as cp  # noqa: F401

# neuromancer symbols are imported in notebook; here they are required indirectly via helper/models loading
from neuromancer.modules import blocks  # type: ignore
from neuromancer.system import Node, System  # type: ignore
from neuromancer.problem import Problem  # type: ignore
from neuromancer.loss import PenaltyLoss  # type: ignore

identification_path = Path.cwd().resolve().parent / 'Identification'
if str(identification_path) not in sys.path:
    sys.path.append(str(identification_path))
import baseline_inference  # type: ignore
# Out:
# Helper imported succesfully

# %%
baseline_inference.init()
# Out:
# Model initialized successfully!
# A matrix shape: (44, 44)
# B matrix shape: (44, 3)
# Scalers loaded for 3 outputs and 3 inputs

# %%
# Resolve project paths (repo root assumed to be parent of this script's CWD)
project_root = os.path.abspath(os.path.join(os.getcwd(), '..'))
src_path = os.path.join(project_root, 'src')
if src_path not in sys.path:
    sys.path.append(src_path)

figures_dir = os.path.join(project_root, 'figures')
os.makedirs(figures_dir, exist_ok=True)

# Local imports from the project
import models  # type: ignore
import helper  # type: ignore

# -----------------------------
# Load matrices, model, scalers
# -----------------------------
matrix_C = False

A = np.load("../data/A_C_False.npy")
B = np.load("../data/B_C_False.npy")
C = np.load("../data/C_C_False.npy")

# Resample A and B from Ts=1 to Ts=10 seconds
Ts_old = 1.0    # original timestep in seconds
Ts_new = 1.0   # desired timestep in seconds

# import scipy.linalg as la

# # Convert to continuous through matrix log
# Ac = la.logm(A) / Ts_old
# Bc = np.linalg.solve(Ac, (A - np.eye(A.shape[0]))) @ B

# # Re-discretize at Ts_new
# A = A_10 = la.expm(Ac * Ts_new)
# B = B_10 = np.linalg.solve(Ac, (A_10 - np.eye(A.shape[0]))) @ Bc

# A = np.real(A)  # or use np.real(A_10) if you're sure
# B = np.real(B)


A_10 = np.linalg.matrix_power(A, int(Ts_new / Ts_old))

sum_term = np.zeros_like(B)
A_power = np.eye(A.shape[0])
for i in range(int(Ts_new / Ts_old)):
    sum_term += A_power @ B
    A_power = A @ A_power
B_10 = sum_term

A = A_10
B = B_10

np.save(f"../data/A_C_{matrix_C}_Ts.npy", A)
np.save(f"../data/B_C_{matrix_C}_Ts.npy", B)

nz, nu = B.shape
ny = C.shape[0]

# disturbance matrix F and dimension nd
F = np.eye(ny)
nd = F.shape[1]
# Out:
# Models imported succesfully

# %%
A
# Out:
# array([[-4.57807854e-02,  5.68538122e-02,  7.05134273e-02,
#          1.89237371e-01, -3.48258689e-02,  3.43724862e-02,
#         -3.05103119e-02,  1.20210946e-01, -1.20429240e-01,
#         -1.23556003e-01, -1.58527136e-01, -1.07860267e-01,
#         -6.19498864e-02,  1.52803198e-01,  8.64541233e-02,
#         -4.80930991e-02, -2.08714157e-01, -3.41052711e-02,
#         -6.97778910e-02,  3.95106114e-02, -8.77776891e-02,
#          1.02032407e-03, -1.85259096e-02, -6.06346130e-02,
#          1.24954097e-01, -6.03060760e-02,  1.03691787e-01,
#          1.76343009e-01,  1.65728956e-01],
#        [ 5.54610677e-02,  3.16128731e-02,  4.35382314e-02,
#         -1.48898408e-01,  1.13972044e-02, -2.57183556e-02,
#         -1.59656540e-01, -1.74568653e-01, -8.03828984e-02,
#         -5.66082597e-02, -1.44156039e-01,  1.35479033e-01,
#          1.55724853e-01,  1.41264513e-01, -5.08171469e-02,
#          3.58843654e-02, -1.30065292e-01,  1.24939568e-01,
#         -6.77164644e-02, -1.09196687e-02, -1.76996902e-01,
#          7.53485784e-02, -5.46697862e-02,  1.12595983e-01,
#          1.51931614e-01,  4.66283299e-02,  1.02895759e-01,
#          1.28252059e-01,  1.29962459e-01],
#        [ 6.27512038e-02, -1.03914842e-01,  1.42397776e-01,
#         -1.58424824e-01, -4.48010229e-02,  1.29554853e-01,
#          1.95747450e-01, -1.09453544e-01, -9.28605795e-02,
#         -1.39484555e-01,  2.50411946e-02,  9.54632312e-02,
#         -9.38996822e-02,  1.69588387e-01,  6.77794665e-02,
#          5.59596680e-02,  1.05749346e-01,  3.32479216e-02,
#         -1.70956835e-01, -7.55863357e-03, -2.77862092e-03,
#         -1.05880655e-01, -4.86352630e-02,  3.75259784e-03,
#         -1.29877716e-01, -1.15559064e-01, -1.45865873e-01,
#         -1.92963585e-01,  1.80013508e-01],
#        [ 1.63407419e-02,  6.41097426e-02, -1.38787419e-01,
#          1.01868205e-01,  2.73173079e-02,  1.07827723e-01,
#          1.04644395e-01, -1.46260664e-01,  1.83073431e-01,
#          1.69498324e-02,  1.80561826e-01,  9.95987952e-02,
#         -4.30613849e-03,  9.51165333e-02, -2.56360695e-03,
#         -9.19095948e-02, -1.65795460e-01, -9.24876109e-02,
#         -1.65842950e-01, -7.85273220e-03, -1.15080528e-01,
#          1.37684643e-01, -1.18281536e-01, -2.16424808e-01,
#          2.00316370e-01,  1.47302777e-01,  1.69952184e-01,
#          1.07444882e-01, -1.58989578e-01],
#        [-1.26442105e-01,  7.06675127e-02,  1.56281710e-01,
#          7.13716745e-02, -8.71916115e-02,  3.42131071e-02,
#          9.24650133e-02, -9.77712348e-02,  9.35522392e-02,
#         -1.11637563e-01, -1.09315112e-01,  6.57903869e-03,
#         -9.19902027e-02, -2.82936785e-02,  1.65745139e-01,
#         -5.89490943e-02, -4.45053577e-02, -5.48314191e-02,
#          1.31183773e-01, -9.00584087e-02, -3.75497602e-02,
#         -1.72395319e-01,  1.74265757e-01,  2.93955375e-02,
#          9.05448198e-02, -1.32341117e-01,  1.81713358e-01,
#          6.20441660e-02,  9.07730833e-02],
#        [-1.66671627e-04, -1.02137864e-01,  1.69007145e-02,
#         -6.83763325e-02,  1.33615956e-01,  6.12676367e-02,
#         -1.23776011e-01,  8.42544362e-02, -8.16500261e-02,
#         -3.03175058e-02, -1.68947130e-01,  1.41279116e-01,
#         -1.42308906e-01, -1.47537500e-01, -2.82571595e-02,
#         -1.05990611e-01, -1.38635129e-01, -2.35123816e-03,
#          1.00913703e-01,  7.20665902e-02, -6.47831112e-02,
#         -1.68657098e-02, -1.24121620e-03, -1.36762172e-01,
#         -1.20624565e-01, -3.49981748e-02,  7.68743008e-02,
#          9.00689885e-02, -3.02915797e-02],
#        [-1.35753676e-01,  8.97615775e-02, -1.00481115e-01,
#          1.59303054e-01, -1.47203937e-01, -1.05434209e-01,
#         -1.21161312e-01, -9.51076150e-02,  4.28519249e-02,
#          3.43623757e-02, -1.21154413e-01,  1.27276793e-01,
#         -2.23401114e-02,  2.65350770e-02, -1.10563353e-01,
#         -1.47160962e-01, -1.26152426e-01,  8.95199329e-02,
#         -1.09714054e-01,  2.42531560e-02,  1.22069418e-02,
#          3.75805795e-02,  1.32433116e-03,  9.80401561e-02,
#         -1.82728693e-01, -6.84002712e-02, -1.22758485e-01,
#          6.11246340e-02,  1.10980771e-01],
#        [-1.16017781e-01,  2.32558884e-02,  1.27486307e-02,
#         -4.70769219e-02, -1.60697788e-01, -1.18053876e-01,
#         -1.91055238e-02,  3.95836458e-02,  6.09561615e-02,
#         -9.05965865e-02,  5.43032251e-02, -9.66141075e-02,
#         -6.63124444e-03,  1.71386600e-01, -1.52708367e-01,
#          4.52404730e-02,  1.82650059e-01, -1.27495095e-01,
#         -1.25127599e-01,  6.94768429e-02,  1.36428192e-01,
#         -3.28489840e-02,  6.65103048e-02,  6.01636134e-02,
#         -5.73244579e-02, -3.80942896e-02,  1.09163284e-01,
#         -1.77061055e-02, -1.69901084e-02],
#        [ 1.35018706e-01,  9.73486453e-02, -1.22813635e-01,
#          6.67450801e-02, -1.09849177e-01, -7.24343257e-03,
#          8.48557130e-02, -2.05691122e-02, -1.43805191e-01,
#         -4.35168929e-02,  5.57133034e-02,  1.41284212e-01,
#          3.64794992e-02, -8.96247802e-04, -1.37913004e-01,
#          1.81153387e-01,  1.13578081e-01, -1.20090358e-01,
#          1.53751578e-04, -1.20994210e-01, -1.28373131e-01,
#         -7.73146600e-02, -3.38814594e-02,  7.59689789e-03,
#         -9.28745344e-02, -1.39324248e-01,  1.33769959e-01,
#          1.73429325e-01,  1.03634521e-01],
#        [-6.91304207e-02, -1.22368068e-01, -1.40901685e-01,
#         -1.44220173e-01,  1.37160674e-01,  6.82793558e-02,
#         -8.37251358e-03,  1.91318184e-01,  1.29944369e-01,
#          1.71766937e-01, -1.72471434e-01,  1.17584817e-01,
#         -1.34191006e-01,  4.60183993e-02,  6.30150959e-02,
#          2.14351788e-01,  5.62046468e-02,  2.92143021e-02,
#          1.78828202e-02, -2.56053191e-02,  1.33932501e-01,
#         -1.14098854e-01,  1.54036328e-01,  7.83375353e-02,
#         -1.39521226e-01,  5.13853244e-02,  5.41791581e-02,
#         -1.12042040e-01,  9.01081413e-02],
#        [-3.28409746e-02,  1.77967370e-01,  2.26533636e-01,
#          1.63074031e-01, -4.09150273e-02,  1.42855912e-01,
#          9.08590034e-02,  1.59842312e-01, -1.30087122e-01,
#         -1.46986261e-01, -1.28416255e-01,  1.71081066e-01,
#          7.98648968e-02,  1.90359101e-01,  3.54189090e-02,
#          6.04438819e-02, -1.01789393e-01,  1.77665398e-01,
#         -1.11590430e-01,  9.54894274e-02,  1.37380660e-01,
#         -1.23257175e-01,  6.45168424e-02, -4.11586016e-02,
#         -5.91331013e-02, -2.06682220e-01, -3.00059374e-02,
#         -2.79780269e-01,  7.31129125e-02],
#        [ 1.53584898e-01,  3.51580940e-02,  8.42659995e-02,
#          7.74919463e-05,  7.29901763e-03,  5.79550415e-02,
#         -6.14578947e-02, -4.25465852e-02, -7.73089379e-02,
#         -9.05874893e-02,  3.68953720e-02,  2.30344743e-01,
#          5.03504649e-02,  5.24738804e-02, -2.05933228e-01,
#         -1.08531162e-01,  4.11104485e-02,  2.79340893e-03,
#         -5.59491776e-02,  5.80476299e-02, -1.05567694e-01,
#         -2.95502995e-03, -1.31922990e-01, -7.60531723e-02,
#          2.04091519e-01, -1.48713201e-01,  1.00786433e-01,
#          1.18187182e-01, -7.55980089e-02],
#        [-6.17188215e-02,  4.57383655e-02, -1.68754876e-01,
#         -3.72631326e-02,  1.34482518e-01, -9.20851156e-02,
#          1.56425387e-01,  8.47660601e-02, -7.36935735e-02,
#          3.99816856e-02,  3.53753679e-02,  1.50256962e-01,
#          8.85678679e-02,  1.30463108e-01,  1.71857588e-02,
#         -1.09294064e-01, -7.19131976e-02, -9.13500190e-02,
#          1.10167347e-01, -1.99660480e-01, -1.25279844e-01,
#          1.28380001e-01, -6.98147640e-02,  8.79299566e-02,
#         -1.04302362e-01,  1.31387874e-01, -5.07263765e-02,
#         -9.17330682e-02, -1.87635601e-01],
#        [ 2.05970369e-02, -8.00061598e-03, -6.86614439e-02,
#          1.05508655e-01, -4.67723198e-02, -1.74054772e-01,
#         -2.01384008e-01,  4.48542684e-02, -1.98856927e-02,
#          4.07033116e-02,  1.13626659e-01, -1.63014621e-01,
#          2.59934235e-02, -1.13506936e-01,  1.28486916e-01,
#          1.43403769e-01, -6.40080497e-02,  6.68698624e-02,
#          1.30673438e-01,  2.81789824e-02,  8.73406902e-02,
#         -9.88715049e-03,  9.57697779e-02,  1.93059579e-01,
#         -1.13533452e-01, -1.51210949e-01,  3.27351429e-02,
#         -9.85942334e-02,  1.72215715e-01],
#        [ 1.69458389e-01,  9.07892510e-02,  9.53140184e-02,
#         -1.02451935e-01,  9.85614806e-02,  1.05367668e-01,
#          1.62865952e-01, -1.03360079e-02, -7.45846005e-03,
#         -1.06693834e-01,  5.84789515e-02,  1.02656588e-01,
#          1.70967698e-01,  1.65049024e-02,  5.14927171e-02,
#         -3.08190603e-02, -5.46390610e-03,  1.39816329e-01,
#          6.51956648e-02, -1.63430750e-01,  7.58247524e-02,
#         -1.37265980e-01, -1.15217656e-01, -1.03391349e-01,
#         -1.70083061e-01, -4.65520695e-02, -1.63741514e-01,
#         -5.61392382e-02,  1.47923976e-01],
#        [-1.04374625e-01, -8.02550018e-02,  1.73852742e-01,
#         -3.21096033e-02,  9.84737650e-02,  1.04464829e-01,
#         -2.01567546e-01,  1.88106492e-01,  6.64310856e-03,
#          1.59496116e-03, -8.43648165e-02, -1.07722178e-01,
#         -1.68560833e-01,  1.01482823e-01, -6.05532080e-02,
#          1.39134660e-01,  1.25926197e-01,  9.31061208e-02,
#         -6.38863668e-02, -5.07698692e-02,  6.77316561e-02,
#         -3.50984409e-02,  1.66005179e-01,  3.96863632e-02,
#         -7.55692795e-02,  6.65162131e-03, -7.15864077e-02,
#          5.89650646e-02,  1.58407569e-01],
#        [-1.76191047e-01, -1.32097468e-01,  1.32535025e-01,
#         -6.04749024e-02, -3.88660431e-02, -9.67351943e-02,
#          7.16671273e-02, -2.15240605e-02,  1.64728433e-01,
#          8.41780677e-02,  1.01488560e-01, -1.18763149e-01,
#          1.50469929e-01,  4.50315736e-02,  3.90321314e-02,
#          6.32605888e-03, -1.23743631e-03,  6.73905984e-02,
#          1.44216463e-01,  1.78282008e-01,  8.73818099e-02,
#          6.67839125e-03,  2.24909380e-01,  1.89899161e-01,
#         -9.71037447e-02,  1.80335000e-01, -1.63114607e-01,
#          1.43583659e-02,  9.71479118e-02],
#        [-1.84751958e-01, -9.86663625e-02, -2.78038345e-02,
#          1.64367966e-02, -1.25178948e-01,  8.41496363e-02,
#         -1.28955260e-01,  9.28597525e-02,  1.03657559e-01,
#          9.34644714e-02, -1.36305466e-01, -5.56959249e-02,
#         -2.15245947e-01,  1.31358907e-01,  7.14445338e-02,
#          3.78765948e-02,  1.77556440e-01, -1.95337832e-01,
#         -8.46917368e-03,  6.58328310e-02, -1.07551873e-01,
#          4.71165441e-02,  9.26150009e-02, -1.30863458e-01,
#          2.22371534e-01,  9.60657448e-02, -1.23545282e-01,
#         -8.39402080e-02, -1.10377885e-01],
#        [-1.08095706e-01,  1.34754017e-01, -7.04262182e-02,
#         -1.21878296e-01, -8.43617395e-02, -1.83093444e-01,
#          1.67881504e-01,  1.24902219e-01,  1.16305627e-01,
#          4.93078120e-02,  5.19814827e-02, -1.92550182e-01,
#          1.82829157e-01,  1.31826565e-01, -3.13465446e-02,
#         -8.28102380e-02,  1.82857037e-01, -5.19481413e-02,
#         -8.79379660e-02, -6.57878816e-02, -1.38273299e-01,
#          9.01743248e-02,  2.37067533e-03,  1.40785858e-01,
#         -1.31123036e-01,  1.01986080e-01, -1.65985793e-01,
#         -8.72111693e-02,  3.17753479e-02],
#        [-2.05576643e-02,  9.31048095e-02,  6.69963509e-02,
#         -1.00514978e-01, -9.19052139e-02, -1.43261105e-01,
#         -3.41504999e-02, -2.80135386e-02, -1.21774554e-01,
#          1.47501558e-01,  2.91293710e-02, -8.21613371e-02,
#          4.50864993e-03,  1.21506989e-01, -5.82353771e-02,
#         -1.37585565e-01, -5.97085841e-02, -8.58361945e-02,
#          2.37382613e-02,  3.75627019e-02, -5.33917211e-02,
#          8.23589936e-02,  8.83159861e-02,  2.06457704e-01,
#         -4.81827259e-02, -6.97844923e-02, -9.54555124e-02,
#          6.09537512e-02, -1.42195687e-01],
#        [-5.29511049e-02, -1.03459574e-01,  4.68564332e-02,
#          2.50648167e-02, -3.93954515e-02, -3.38133276e-02,
#         -4.05063592e-02,  2.12496947e-02, -1.69680908e-01,
#          1.48803703e-02, -1.12937398e-01, -3.00969407e-02,
#         -1.04381606e-01,  1.51307553e-01, -1.52441353e-01,
#          1.45914510e-01, -1.13637999e-01,  1.53807372e-01,
#          5.81559688e-02,  1.72743455e-01,  1.26946330e-01,
#         -4.34407629e-02,  1.79788440e-01, -1.16931640e-01,
#          3.19398269e-02,  4.01631109e-02, -8.24157074e-02,
#         -1.76140323e-01,  9.78505984e-02],
#        [-6.96676373e-02, -5.94917350e-02, -8.06344971e-02,
#         -1.65285707e-01,  1.80708408e-01, -3.97260115e-02,
#          1.30873039e-01, -4.50035930e-02,  1.55425102e-01,
#         -3.61845046e-02,  3.68145145e-02, -9.77600068e-02,
#         -3.68072987e-02,  1.07687265e-01, -1.67146549e-01,
#         -1.30361974e-01,  1.41517580e-01, -2.25127742e-01,
#         -1.52353972e-01,  3.30141000e-02, -5.18127717e-02,
#          7.45674670e-02,  7.97590166e-02, -9.66137871e-02,
#         -1.29196569e-01, -7.26992339e-02,  5.58546223e-02,
#          3.14416029e-02,  1.44866914e-01],
#        [ 6.25416711e-02, -1.97676092e-01, -1.01124264e-01,
#         -1.14261985e-01,  4.14012745e-03, -7.96352606e-03,
#          5.86313047e-02,  3.33994515e-02, -1.13999158e-01,
#         -8.92788023e-02, -1.47821405e-03, -3.57588707e-03,
#         -1.41756088e-01,  3.58366296e-02,  1.32759344e-02,
#          2.20210612e-01,  9.66388360e-02,  2.58989092e-02,
#          6.57792091e-02,  1.38236299e-01, -5.40040620e-02,
#          5.20522892e-02,  2.84891296e-03,  1.47743672e-01,
#         -1.25297308e-01, -1.42807558e-01, -1.22440029e-02,
#          8.84367451e-02,  1.28898527e-02],
#        [ 9.84268188e-02,  3.53114307e-02, -3.43418717e-02,
#         -1.26921192e-01,  3.87272872e-02,  2.76369974e-02,
#         -1.96554050e-01,  7.92535171e-02, -1.25833005e-01,
#          1.43271416e-01, -3.35816704e-02, -4.40721475e-02,
#         -1.24899838e-02,  1.07755750e-01, -4.84255701e-02,
#          5.62263746e-03, -5.39810061e-02,  1.30697057e-01,
#         -1.55120492e-02,  3.94218750e-02,  8.57456401e-02,
#          6.36862442e-02, -7.07029924e-02, -1.16727121e-01,
#          5.11319377e-02,  9.43262782e-03, -9.34314579e-02,
#          8.53947476e-02, -6.42701089e-02],
#        [ 1.48378834e-01,  3.62845995e-02, -8.92533734e-02,
#          1.30341128e-01, -2.68921982e-02, -3.90784182e-02,
#          4.68161665e-02, -2.02017456e-01, -5.25360145e-02,
#         -6.15331307e-02, -2.87958253e-02,  2.11875066e-01,
#         -7.37917423e-02,  2.88142879e-02,  8.03415179e-02,
#          2.10309885e-02, -9.20512713e-03,  1.22681029e-01,
#         -7.44501129e-02,  4.70684730e-02,  3.21069025e-02,
#          1.26825705e-01, -1.48336112e-01,  1.05952770e-01,
#          6.26291782e-02,  1.04763873e-01, -1.46584824e-01,
#         -8.52045640e-02,  1.33362100e-01],
#        [-1.05222017e-01, -1.63267300e-01, -1.75812155e-01,
#         -9.43641216e-02, -1.19144350e-01,  7.56134987e-02,
#          3.55463438e-02,  9.42721963e-03, -7.84083307e-02,
#         -4.92585450e-02, -1.64310411e-01, -1.44016489e-01,
#          1.11416712e-01,  1.15774823e-02,  4.83036116e-02,
#          8.97630006e-02, -1.61575153e-01,  3.07040736e-02,
#         -7.56129716e-03,  1.43929154e-01,  1.29213646e-01,
#         -5.48600666e-02,  5.19725755e-02,  6.49984181e-02,
#         -1.83538407e-01,  1.76790357e-02, -1.34454578e-01,
#         -3.45440619e-02,  7.46244267e-02],
#        [-3.02242134e-02,  8.30141902e-02, -9.29763075e-03,
#         -1.54087633e-01, -4.90076914e-02, -1.65769979e-01,
#          9.06025022e-02, -3.62701081e-02,  5.52328229e-02,
#         -6.01960234e-02,  1.36897206e-01,  5.03056608e-02,
#          1.63651362e-01, -3.72813381e-02,  1.85602635e-01,
#         -1.88691989e-01, -1.98559240e-01,  5.51078049e-03,
#          5.55789769e-02,  8.94828886e-02, -1.58221945e-01,
#         -3.49574983e-02,  1.09562464e-01,  4.92965207e-02,
#         -1.02464065e-01, -1.50081709e-01, -2.74669603e-02,
#          1.80518404e-02,  7.95580521e-02],
#        [ 5.27779423e-02,  1.20457165e-01, -1.42861940e-02,
#          6.85712025e-02, -2.90354993e-02, -1.07020497e-01,
#          2.61370428e-02, -1.88759252e-01,  1.02557480e-01,
#          4.90988381e-02, -7.31319860e-02, -6.21833745e-03,
#         -6.33287951e-02, -1.12942614e-01,  1.09090507e-01,
#         -6.23473339e-03, -1.59967676e-01,  8.12093690e-02,
#          1.30118489e-01,  9.16576684e-02, -6.11961409e-02,
#         -6.59762770e-02,  1.95133075e-01, -1.19337723e-01,
#         -7.03607798e-02, -2.23266650e-02,  1.38581604e-01,
#         -2.12026723e-02,  1.22240625e-01],
#        [ 5.89999817e-02, -1.44907748e-02, -1.15852751e-01,
#         -9.05063376e-02, -3.47914174e-02, -7.52826855e-02,
#          1.39485031e-01, -1.60115093e-01,  1.54162839e-01,
#          1.54077560e-01,  1.51035815e-01, -9.94850621e-02,
#          8.55047703e-02,  1.01160027e-01, -2.44092062e-01,
#          1.18310124e-01, -1.38769552e-01, -1.88456059e-01,
#          8.17112327e-02,  3.45839362e-04, -6.74096346e-02,
#         -8.02696869e-02,  1.75587133e-01,  1.20287962e-01,
#         -6.20234087e-02,  1.15509547e-01,  1.78753167e-01,
#          5.28381430e-02, -2.99157333e-02]], dtype=float32)

# %%
# Block-diagonalize A using helper
T_real, A_block = helper.ident.real_block_diagonalize(A)

# Transform A to check
A_transformed = inv(T_real) @ A @ T_real
print('Close to block diagonal?', np.allclose(A_block, A_transformed, atol=1e-6))

# Backtransform A_block to verify it equals A
A_backtransformed = T_real @ A_block @ inv(T_real)
print('Backtransformation equals original A?', np.allclose(A, A_backtransformed, atol=1e-6))

# Apply similarity transform to A, B, C
A = A_block
B = inv(T_real) @ B
C = C @ T_real

# -----------------------------
# Build Koopman model components
# -----------------------------
cons = 3
layers = [6*cons,12*cons,18*cons]
layers_dec  = [18*cons,12*cons,6*cons]

# Output encoder f_y
f_y = blocks.MLP(
    ny,
    nz,
    bias=True,
    linear_map=torch.nn.Linear,
    nonlin=torch.nn.ReLU,
    hsizes=layers,
)
encode_Y0 = Node(f_y, ['Y0'], ['x'], name='encoder_Y0')
encode_Y = Node(f_y, ['Y'], ['x_latent'], name='encoder_Y')

# Input encoder f_u representing B in linear system
f_u = torch.nn.Linear(nu, nz, bias=False)
encode_U = Node(f_u, ['U'], ['u_latent'], name='encoder_U')

# State decoder f_y_inv
if not matrix_C:
    f_y_inv = blocks.MLP(
        nz,
        ny,
        bias=True,
        linear_map=torch.nn.Linear,
        nonlin=torch.nn.ELU,
        hsizes=layers_dec,
    )
elif matrix_C:
    f_y_inv = torch.nn.Linear(nz, ny, bias=False)
else:
    raise ValueError('matrix_C must be boolean')

decode_y = Node(f_y_inv, ['x'], ['yhat'], name='decoder_y')

# Linear map K for latent dynamics
K = torch.nn.Linear(nz, nz, bias=False)

# Symbolic Koopman model with control inputs
Koopman = Node(helper.PredictionWControl(K), ['x', 'u_latent'], ['x'], name='K')
dynamics_model = System([Koopman], name='Koopman', nsteps=1)

nodes = [encode_Y0, encode_Y, encode_U, dynamics_model, decode_y]
loss = PenaltyLoss([], constraints=[])
problem = Problem(nodes, loss)

problem.load_state_dict(
    torch.load(os.path.join(project_root, 'data', f'model_C_{matrix_C}.pth')),
    strict=False,
)

# -----------------------------
# Load scalers and plant model
# -----------------------------
scaler = joblib.load(os.path.join(project_root, 'data', 'scaler.pkl'))
scalerU = joblib.load(os.path.join(project_root, 'data', 'scalerU.pkl'))
# Out:
# Close to block diagonal? True
# Backtransformation equals original A? True

# %%
# Plant model: use full nonlinear CSTR series with recycle for simulation

# Helper conversion utilities
def get_x(y: np.ndarray) -> np.ndarray:
    x = problem.nodes[0]({'Y0': torch.from_numpy(y).float()})
    return x['x'].detach().numpy().reshape(1, -1).T

def get_y(x: np.ndarray) -> np.ndarray:
    y = problem.nodes[4]({'x': torch.from_numpy(x.T).float()})
    return y['yhat'].detach().numpy().reshape(1, -1)

def get_y_vector(x: np.ndarray) -> np.ndarray:
    y = problem.nodes[4]({'x': torch.from_numpy(x.T).float()})
    return y['yhat'].detach().numpy()
# -----------------------------
# Observer - Kalman filter setup
# -----------------------------
loaded_setup = joblib.load(os.path.join(os.getcwd(), 'sim_setup.pkl'))

y_start = loaded_setup['y_start']
y_start_ns = loaded_setup.get('y_start_ns')
reference_ns = loaded_setup.get('reference_ns')
y_setpoint = loaded_setup['reference'][:, 0]
u_previous = loaded_setup['u_previous']
u_previous_ns = loaded_setup.get('u_previous_ns')

z_est_ = np.hstack(((inv(T_real) @ get_x(y_start)).T, np.zeros((1, nd))))
P0 = np.eye(nz + nd)*loaded_setup['P0']
Q = np.eye(nz + nd)*loaded_setup['Q']  # process noise
R = np.eye(ny)*loaded_setup['R']  # measurement noise

A_ = np.block([
    [A, np.zeros((nz, nd))],
    [np.zeros((nd, nz)), np.eye(nd)],
])
B_ = np.vstack([
    B,
    np.zeros((nd, nu)),
])

EKF = helper.EKF(A_, B_, z_est_, P0, problem, Q, R, 3, T_real)
# EKF = helper.EKF_C(A_, B_, C, z_est_, P0, problem, Q, Rm, 2, T_real)

# -----------------------------
# Target calculation
# -----------------------------
target_estimation = helper.TaylorTargetEstimation(A, B)

J = helper.evaluate_jacobian(
    problem.nodes[4],
    torch.from_numpy(T_real @ z_est_[0, :nz]).float(),
) @ T_real

z_s, y_s, u_s = target_estimation.get_target(
    z_est_[:, nz:], y_setpoint, get_y(T_real @ z_est_[0, :nz]), z_est_[0, :nz], J
)
print(target_estimation.te.status)
print('Optimal y:', scaler.inverse_transform(y_s.reshape(1, -1)))
print('Desired y:', scaler.inverse_transform(y_setpoint.reshape(1, -1)))
print('Optimal u:', scalerU.inverse_transform(target_estimation.u_s.value.reshape(1, -1)))
z_ref = z_s
# Out:
# Set parameter Username
# Set parameter LicenseID to value 2631450
# Academic license - for non-commercial use only - expires 2026-03-05
# optimal
# Optimal y: [[56.580627   74.890015   56.13717001]]
# Desired y: [[56.580627 74.890015 56.13717 ]]
# Optimal u: [[87.51921046 51.32857252 45.58841923]]
# /Users/patrik/miniconda3/envs/kmpc/lib/python3.11/site-packages/cvxpy/reductions/solvers/solving_chain.py:245: UserWarning: You are solving a parameterized problem that is not DPP. Because the problem is not DPP, subsequent solves will not be faster than the first one. For more information, see the documentation on Disciplined Parametrized Programming, at https://www.cvxpy.org/tutorial/dpp/index.html
#   warnings.warn(DPP_ERROR_MSG)

# %%
# -----------------------------
# MPC problem formulation
# -----------------------------
Qy = loaded_setup['Qy']
J = helper.evaluate_jacobian(
    problem.nodes[4],
    torch.from_numpy(T_real @ z_s).float(),
) @ T_real
Qz = J.T @ Qy @ J
Qz_psd = Qz + 1e-8 * np.eye(Qz.shape[0])

mpc = helper.TaylorMPC(A, B)
mpc.build_problem(Qz_psd)
u_opt = mpc.get_u_optimal(
    z_est_[0, :nz], z_est_[:, nz:], u_previous, z_ref, get_y(T_real @ z_s), z_s, J
)
print(u_opt)
print(mpc.mpc.status)
# Out:
# /Users/patrik/miniconda3/envs/kmpc/lib/python3.11/site-packages/cvxpy/reductions/solvers/solving_chain.py:245: UserWarning: You are solving a parameterized problem that is not DPP. Because the problem is not DPP, subsequent solves will not be faster than the first one. For more information, see the documentation on Disciplined Parametrized Programming, at https://www.cvxpy.org/tutorial/dpp/index.html
#   warnings.warn(DPP_ERROR_MSG)
# [ 0.86287641  0.6168032  -0.24266465]
# optimal

# %%
baseline_inference.get_x(y_start)

# %%
int(Ts_new-1)
# Out:
# 0

# %%
# -----------------------------
# Closed-loop simulation
# -----------------------------
sim_time = loaded_setup['sim_time']
Ts = 1
z_sim = np.zeros((nz + nd, sim_time + 1))
y_sim = np.zeros((ny, sim_time + 1))
y_pred = np.zeros((ny, sim_time + 1))
u_sim = np.zeros((nu, sim_time))
us_sim = np.zeros((nu, sim_time + 1))
ys_sim = np.zeros((ny, sim_time + 1))
zs_sim = np.zeros((nz, sim_time + 1))
us_sim = np.zeros((nu, sim_time + 1))

total_time_target = 0.0
total_time_mpc = 0.0

start_time_target = time.time()
z_s, y_s, u_s = target_estimation.get_target(
    z_est_[:, nz:], y_setpoint, get_y(T_real @ z_s), z_s, J
)
end_time_target = time.time()
total_time_target += end_time_target - start_time_target

y_sim_descaled = np.zeros((ny, sim_time + 1))
u_sim_descaled = np.zeros((nu, sim_time))

z_sim[:, 0] = z_est_.flatten()
y_sim[:, 0] = y_start.flatten()
ys_sim[:, 0] = y_s
zs_sim[:, 0] = z_s
u_prev = target_estimation.u_s.value
u_sim_descaled[:, 0] = scalerU.inverse_transform(u_sim[:, 0].reshape(1, -1))[0]
y_sim_descaled[:, 0] = scaler.inverse_transform(y_sim[:, 0].reshape(1, -1))[0]

from tqdm import trange
for k in trange(sim_time):
    y_setpoint = loaded_setup['reference'][:, k]
    idx_prev = max(k - 1, 0)

    # target update (T2): linearize at previous target zs_sim[:, k]
    J = helper.evaluate_jacobian(
        problem.nodes[4],
        torch.from_numpy(T_real @ zs_sim[:, idx_prev]).float(),
    ) @ T_real
    start_time_target = time.time()
    zs_sim[:, k], ys_sim[:, k], us_sim[:, k] = target_estimation.get_target(
        z_sim[nz:, k], 
        y_setpoint, 
        get_y(T_real @ zs_sim[:, idx_prev]), 
        zs_sim[:, idx_prev], 
        J
    )
    y_pred[:,k] = J@z_sim[:nz,k] + get_y(T_real @ zs_sim[:, idx_prev]) - J @ zs_sim[:, idx_prev]
    end_time_target = time.time()
    total_time_target += end_time_target - start_time_target

    # T2/D2: for MPC, linearize at the previous target zs_sim[:, k-1] (use k=0 fallback)
    # J_prev = helper.evaluate_jacobian(
    #     problem.nodes[4],
    #     torch.from_numpy(T_real @ zs_sim[:, idx_prev]).float(),
    # ) @ T_real
    # J = J_prev

    # if k > 0:
    Qz = J.T @ Qy @ J
    Qz_psd = Qz + 1e-8 * np.eye(Qz.shape[0])
    mpc.build_problem(Qz_psd)

    start_time_mpc = time.time()
    u_opt = mpc.get_u_optimal(
        z_sim[:nz, k],
        z_sim[nz:, k],
        u_prev,
        zs_sim[:, k],
        get_y(T_real @ zs_sim[:, idx_prev]),
        zs_sim[:, idx_prev],
        J,
    )
    end_time_mpc = time.time()
    total_time_mpc += end_time_mpc - start_time_mpc

    u_sim[:, k] = u_opt
    u_sim_descaled[:, k] = scalerU.inverse_transform(u_sim[:, k].reshape(1, -1))[0]

    # simulate plant in physical space
    for i in range(int(Ts_new-1)):
        baseline_inference.y_plus(u_sim[:, k])
    y_sim[:, k + 1] = baseline_inference.y_plus(u_sim[:, k])
    y_sim_descaled[:, k + 1] = scaler.inverse_transform(y_sim[:, k + 1].reshape(1, -1))[0]

    # state estimation
    z_sim[:, k + 1] = EKF.step(u_sim[:, k], y_sim[:, k + 1]).flatten()

    u_prev = u_sim[:, k]

print(f'Total time spent in target estimation: {total_time_target:.4f} seconds')
print(f'Total time spent in MPC solve: {total_time_mpc:.4f} seconds')
# Out:
#   0%|          | 0/500 [00:00<?, ?it/s]/Users/patrik/miniconda3/envs/kmpc/lib/python3.11/site-packages/cvxpy/reductions/solvers/solving_chain.py:245: UserWarning: You are solving a parameterized problem that is not DPP. Because the problem is not DPP, subsequent solves will not be faster than the first one. For more information, see the documentation on Disciplined Parametrized Programming, at https://www.cvxpy.org/tutorial/dpp/index.html
#   warnings.warn(DPP_ERROR_MSG)
#   0%|          | 1/500 [00:00<04:14,  1.96it/s]/Users/patrik/miniconda3/envs/kmpc/lib/python3.11/site-packages/cvxpy/reductions/solvers/solving_chain.py:245: UserWarning: You are solving a parameterized problem that is not DPP. Because the problem is not DPP, subsequent solves will not be faster than the first one. For more information, see the documentation on Disciplined Parametrized Programming, at https://www.cvxpy.org/tutorial/dpp/index.html
#   warnings.warn(DPP_ERROR_MSG)
#   0%|          | 2/500 [00:00<03:30,  2.36it/s]/Users/patrik/miniconda3/envs/kmpc/lib/python3.11/site-packages/cvxpy/reductions/solvers/solving_chain.py:245: UserWarning: You are solving a parameterized problem that is not DPP. Because the problem is not DPP, subsequent solves will not be faster than the first one. For more information, see the documentation on Disciplined Parametrized Programming, at https://www.cvxpy.org/tutorial/dpp/index.html
#   warnings.warn(DPP_ERROR_MSG)
#   1%|          | 3/500 [00:01<03:39,  2.27it/s]/Users/patrik/miniconda3/envs/kmpc/lib/python3.11/site-packages/cvxpy/reductions/solvers/solving_chain.py:245: UserWarning: You are solving a parameterized problem that is not DPP. Because the problem is not DPP, subsequent solves will not be faster than the first one. For more information, see the documentation on Disciplined Parametrized Programming, at https://www.cvxpy.org/tutorial/dpp/index.html
#   warnings.warn(DPP_ERROR_MSG)
#   1%|          | 4/500 [00:01<03:52,  2.14it/s]/Users/patrik/miniconda3/envs/kmpc/lib/python3.11/site-packages/cvxpy/reductions/solvers/solving_chain.py:245: UserWarning: You are solving a parameterized problem that is not DPP. Because the problem is not DPP, subsequent solves will not be faster than the first one. For more information, see the documentation on Disciplined Parametrized Programming, at https://www.cvxpy.org/tutorial/dpp/index.html
#   warnings.warn(DPP_ERROR_MSG)
#   1%|          | 5/500 [00:02<03:31,  2.34it/s]/Users/patrik/miniconda3/envs/kmpc/lib/python3.11/site-packages/cvxpy/reductions/solvers/solving_chain.py:245: UserWarning: You are solving a parameterized problem that is not DPP. Because the problem is not DPP, subsequent solves will not be faster than the first one. For more information, see the documentation on Disciplined Parametrized Programming, at https://www.cvxpy.org/tutorial/dpp/index.html
#   warnings.warn(DPP_ERROR_MSG)
#   1%|          | 6/500 [00:02<03:46,  2.18it/s]/Users/patrik/miniconda3/envs/kmpc/lib/python3.11/site-packages/cvxpy/reductions/solvers/solving_chain.py:245: UserWarning: You are solving a parameterized problem that is not DPP. Because the problem is not DPP, subsequent solves will not be faster than the first one. For more information, see the documentation on Disciplined Parametrized Programming, at https://www.cvxpy.org/tutorial/dpp/index.html
#   warnings.warn(DPP_ERROR_MSG)
#   1%|▏         | 7/500 [00:03<03:29,  2.35it/s]/Users/patrik/miniconda3/envs/kmpc/lib/python3.11/site-packages/cvxpy/reductions/solvers/solving_chain.py:245: UserWarning: You are solving a parameterized problem that is not DPP. Because the problem is not DPP, subsequent solves will not be faster than the first one. For more information, see the documentation on Disciplined Parametrized Programming, at https://www.cvxpy.org/tutorial/dpp/index.html
#   warnings.warn(DPP_ERROR_MSG)
#   2%|▏         | 8/500 [00:03<03:20,  2.45it/s]/Users/patrik/miniconda3/envs/kmpc/lib/python3.11/site-packages/cvxpy/reductions/solvers/solving_chain.py:245: UserWarning: You are solving a parameterized problem that is not DPP. Because the problem is not DPP, subsequent solves will not be faster than the first one. For more information, see the documentation on Disciplined Parametrized Programming, at https://www.cvxpy.org/tutorial/dpp/index.html
#   warnings.warn(DPP_ERROR_MSG)
#   2%|▏         | 9/500 [00:04<03:59,  2.05it/s]/Users/patrik/miniconda3/envs/kmpc/lib/python3.11/site-packages/cvxpy/reductions/solvers/solving_chain.py:245: UserWarning: You are solving a parameterized problem that is not DPP. Because the problem is not DPP, subsequent solves will not be faster than the first one. For more information, see the documentation on Disciplined Parametrized Programming, at https://www.cvxpy.org/tutorial/dpp/index.html
#   warnings.warn(DPP_ERROR_MSG)
#   2%|▏         | 10/500 [00:04<03:59,  2.05it/s]/Users/patrik/miniconda3/envs/kmpc/lib/python3.11/site-packages/cvxpy/reductions/solvers/solving_chain.py:245: UserWarning: You are solving a parameterized problem that is not DPP. Because the problem is not DPP, subsequent solves will not be faster than the first one. For more information, see the documentation on Disciplined Parametrized Programming, at https://www.cvxpy.org/tutorial/dpp/index.html
#   warnings.warn(DPP_ERROR_MSG)
#   2%|▏         | 11/500 [00:05<04:09,  1.96it/s]/Users/patrik/miniconda3/envs/kmpc/lib/python3.11/site-packages/cvxpy/reductions/solvers/solving_chain.py:245: UserWarning: You are solving a parameterized problem that is not DPP. Because the problem is not DPP, subsequent solves will not be faster than the first one. For more information, see the documentation on Disciplined Parametrized Programming, at https://www.cvxpy.org/tutorial/dpp/index.html
#   warnings.warn(DPP_ERROR_MSG)
#   2%|▏         | 12/500 [00:05<04:21,  1.87it/s]/Users/patrik/miniconda3/envs/kmpc/lib/python3.11/site-packages/cvxpy/reductions/solvers/solving_chain.py:245: UserWarning: You are solving a parameterized problem that is not DPP. Because the problem is not DPP, subsequent solves will not be faster than the first one. For more information, see the documentation on Disciplined Parametrized Programming, at https://www.cvxpy.org/tutorial/dpp/index.html
#   warnings.warn(DPP_ERROR_MSG)
#   3%|▎         | 13/500 [00:06<04:20,  1.87it/s]/Users/patrik/miniconda3/envs/kmpc/lib/python3.11/site-packages/cvxpy/reductions/solvers/solving_chain.py:245: UserWarning: You are solving a parameterized problem that is not DPP. Because the problem is not DPP, subsequent solves will not be faster than the first one. For more information, see the documentation on Disciplined Parametrized Programming, at https://www.cvxpy.org/tutorial/dpp/index.html
#   warnings.warn(DPP_ERROR_MSG)
#   3%|▎         | 14/500 [00:07<05:40,  1.43it/s]/Users/patrik/miniconda3/envs/kmpc/lib/python3.11/site-packages/cvxpy/reductions/solvers/solving_chain.py:245: UserWarning: You are solving a parameterized problem that is not DPP. Because the problem is not DPP, subsequent solves will not be faster than the first one. For more information, see the documentation on Disciplined Parametrized Programming, at https://www.cvxpy.org/tutorial/dpp/index.html
#   warnings.warn(DPP_ERROR_MSG)
#   3%|▎         | 15/500 [00:07<04:58,  1.63it/s]/Users/patrik/miniconda3/envs/kmpc/lib/python3.11/site-packages/cvxpy/reductions/solvers/solving_chain.py:245: UserWarning: You are solving a parameterized problem that is not DPP. Because the problem is not DPP, subsequent solves will not be faster than the first one. For more information, see the documentation on Disciplined Parametrized Programming, at https://www.cvxpy.org/tutorial/dpp/index.html
#   warnings.warn(DPP_ERROR_MSG)
#   3%|▎         | 16/500 [00:08<04:36,  1.75it/s]/Users/patrik/miniconda3/envs/kmpc/lib/python3.11/site-packages/cvxpy/reductions/solvers/solving_chain.py:245: UserWarning: You are solving a parameterized problem that is not DPP. Because the problem is not DPP, subsequent solves will not be faster than the first one. For more information, see the documentation on Disciplined Parametrized Programming, at https://www.cvxpy.org/tutorial/dpp/index.html
#   warnings.warn(DPP_ERROR_MSG)
#   3%|▎         | 17/500 [00:08<04:37,  1.74it/s]/Users/patrik/miniconda3/envs/kmpc/lib/python3.11/site-packages/cvxpy/reductions/solvers/solving_chain.py:245: UserWarning: You are solving a parameterized problem that is not DPP. Because the problem is not DPP, subsequent solves will not be faster than the first one. For more information, see the documentation on Disciplined Parametrized Programming, at https://www.cvxpy.org/tutorial/dpp/index.html
#   warnings.warn(DPP_ERROR_MSG)
#   4%|▎         | 18/500 [00:09<04:31,  1.78it/s]/Users/patrik/miniconda3/envs/kmpc/lib/python3.11/site-packages/cvxpy/reductions/solvers/solving_chain.py:245: UserWarning: You are solving a parameterized problem that is not DPP. Because the problem is not DPP, subsequent solves will not be faster than the first one. For more information, see the documentation on Disciplined Parametrized Programming, at https://www.cvxpy.org/tutorial/dpp/index.html
#   warnings.warn(DPP_ERROR_MSG)
#   4%|▍         | 19/500 [00:09<04:23,  1.82it/s]/Users/patrik/miniconda3/envs/kmpc/lib/python3.11/site-packages/cvxpy/reductions/solvers/solving_chain.py:245: UserWarning: You are solving a parameterized problem that is not DPP. Because the problem is not DPP, subsequent solves will not be faster than the first one. For more information, see the documentation on Disciplined Parametrized Programming, at https://www.cvxpy.org/tutorial/dpp/index.html
#   warnings.warn(DPP_ERROR_MSG)
#   4%|▍         | 20/500 [00:10<04:41,  1.70it/s]/Users/patrik/miniconda3/envs/kmpc/lib/python3.11/site-packages/cvxpy/reductions/solvers/solving_chain.py:245: UserWarning: You are solving a parameterized problem that is not DPP. Because the problem is not DPP, subsequent solves will not be faster than the first one. For more information, see the documentation on Disciplined Parametrized Programming, at https://www.cvxpy.org/tutorial/dpp/index.html
#   warnings.warn(DPP_ERROR_MSG)
#   4%|▍         | 21/500 [00:10<04:13,  1.89it/s]/Users/patrik/miniconda3/envs/kmpc/lib/python3.11/site-packages/cvxpy/reductions/solvers/solving_chain.py:245: UserWarning: You are solving a parameterized problem that is not DPP. Because the problem is not DPP, subsequent solves will not be faster than the first one. For more information, see the documentation on Disciplined Parametrized Programming, at https://www.cvxpy.org/tutorial/dpp/index.html
#   warnings.warn(DPP_ERROR_MSG)
#   4%|▍         | 22/500 [00:11<03:47,  2.10it/s]/Users/patrik/miniconda3/envs/kmpc/lib/python3.11/site-packages/cvxpy/reductions/solvers/solving_chain.py:245: UserWarning: You are solving a parameterized problem that is not DPP. Because the problem is not DPP, subsequent solves will not be faster than the first one. For more information, see the documentation on Disciplined Parametrized Programming, at https://www.cvxpy.org/tutorial/dpp/index.html
#   warnings.warn(DPP_ERROR_MSG)
#   5%|▍         | 23/500 [00:11<03:57,  2.00it/s]/Users/patrik/miniconda3/envs/kmpc/lib/python3.11/site-packages/cvxpy/reductions/solvers/solving_chain.py:245: UserWarning: You are solving a parameterized problem that is not DPP. Because the problem is not DPP, subsequent solves will not be faster than the first one. For more information, see the documentation on Disciplined Parametrized Programming, at https://www.cvxpy.org/tutorial/dpp/index.html
#   warnings.warn(DPP_ERROR_MSG)
#   5%|▍         | 24/500 [00:12<03:40,  2.16it/s]/Users/patrik/miniconda3/envs/kmpc/lib/python3.11/site-packages/cvxpy/reductions/solvers/solving_chain.py:245: UserWarning: You are solving a parameterized problem that is not DPP. Because the problem is not DPP, subsequent solves will not be faster than the first one. For more information, see the documentation on Disciplined Parametrized Programming, at https://www.cvxpy.org/tutorial/dpp/index.html
#   warnings.warn(DPP_ERROR_MSG)
#   5%|▌         | 25/500 [00:12<03:33,  2.23it/s]/Users/patrik/miniconda3/envs/kmpc/lib/python3.11/site-packages/cvxpy/reductions/solvers/solving_chain.py:245: UserWarning: You are solving a parameterized problem that is not DPP. Because the problem is not DPP, subsequent solves will not be faster than the first one. For more information, see the documentation on Disciplined Parametrized Programming, at https://www.cvxpy.org/tutorial/dpp/index.html
#   warnings.warn(DPP_ERROR_MSG)
#   5%|▌         | 26/500 [00:13<03:37,  2.18it/s]/Users/patrik/miniconda3/envs/kmpc/lib/python3.11/site-packages/cvxpy/reductions/solvers/solving_chain.py:245: UserWarning: You are solving a parameterized problem that is not DPP. Because the problem is not DPP, subsequent solves will not be faster than the first one. For more information, see the documentation on Disciplined Parametrized Programming, at https://www.cvxpy.org/tutorial/dpp/index.html
#   warnings.warn(DPP_ERROR_MSG)
#   5%|▌         | 27/500 [00:13<04:09,  1.90it/s]/Users/patrik/miniconda3/envs/kmpc/lib/python3.11/site-packages/cvxpy/reductions/solvers/solving_chain.py:245: UserWarning: You are solving a parameterized problem that is not DPP. Because the problem is not DPP, subsequent solves will not be faster than the first one. For more information, see the documentation on Disciplined Parametrized Programming, at https://www.cvxpy.org/tutorial/dpp/index.html
#   warnings.warn(DPP_ERROR_MSG)
#   6%|▌         | 28/500 [00:14<04:34,  1.72it/s]/Users/patrik/miniconda3/envs/kmpc/lib/python3.11/site-packages/cvxpy/reductions/solvers/solving_chain.py:245: UserWarning: You are solving a parameterized problem that is not DPP. Because the problem is not DPP, subsequent solves will not be faster than the first one. For more information, see the documentation on Disciplined Parametrized Programming, at https://www.cvxpy.org/tutorial/dpp/index.html
#   warnings.warn(DPP_ERROR_MSG)
#   6%|▌         | 29/500 [00:14<04:12,  1.87it/s]/Users/patrik/miniconda3/envs/kmpc/lib/python3.11/site-packages/cvxpy/reductions/solvers/solving_chain.py:245: UserWarning: You are solving a parameterized problem that is not DPP. Because the problem is not DPP, subsequent solves will not be faster than the first one. For more information, see the documentation on Disciplined Parametrized Programming, at https://www.cvxpy.org/tutorial/dpp/index.html
#   warnings.warn(DPP_ERROR_MSG)
#   6%|▌         | 30/500 [00:15<03:47,  2.06it/s]/Users/patrik/miniconda3/envs/kmpc/lib/python3.11/site-packages/cvxpy/reductions/solvers/solving_chain.py:245: UserWarning: You are solving a parameterized problem that is not DPP. Because the problem is not DPP, subsequent solves will not be faster than the first one. For more information, see the documentation on Disciplined Parametrized Programming, at https://www.cvxpy.org/tutorial/dpp/index.html
#   warnings.warn(DPP_ERROR_MSG)
#   6%|▌         | 31/500 [00:15<03:53,  2.01it/s]/Users/patrik/miniconda3/envs/kmpc/lib/python3.11/site-packages/cvxpy/reductions/solvers/solving_chain.py:245: UserWarning: You are solving a parameterized problem that is not DPP. Because the problem is not DPP, subsequent solves will not be faster than the first one. For more information, see the documentation on Disciplined Parametrized Programming, at https://www.cvxpy.org/tutorial/dpp/index.html
#   warnings.warn(DPP_ERROR_MSG)
#   6%|▋         | 32/500 [00:16<03:34,  2.18it/s]/Users/patrik/miniconda3/envs/kmpc/lib/python3.11/site-packages/cvxpy/reductions/solvers/solving_chain.py:245: UserWarning: You are solving a parameterized problem that is not DPP. Because the problem is not DPP, subsequent solves will not be faster than the first one. For more information, see the documentation on Disciplined Parametrized Programming, at https://www.cvxpy.org/tutorial/dpp/index.html
#   warnings.warn(DPP_ERROR_MSG)
#   7%|▋         | 33/500 [00:16<03:20,  2.33it/s]/Users/patrik/miniconda3/envs/kmpc/lib/python3.11/site-packages/cvxpy/reductions/solvers/solving_chain.py:245: UserWarning: You are solving a parameterized problem that is not DPP. Because the problem is not DPP, subsequent solves will not be faster than the first one. For more information, see the documentation on Disciplined Parametrized Programming, at https://www.cvxpy.org/tutorial/dpp/index.html
#   warnings.warn(DPP_ERROR_MSG)
#   7%|▋         | 34/500 [00:17<03:51,  2.01it/s]/Users/patrik/miniconda3/envs/kmpc/lib/python3.11/site-packages/cvxpy/reductions/solvers/solving_chain.py:245: UserWarning: You are solving a parameterized problem that is not DPP. Because the problem is not DPP, subsequent solves will not be faster than the first one. For more information, see the documentation on Disciplined Parametrized Programming, at https://www.cvxpy.org/tutorial/dpp/index.html
#   warnings.warn(DPP_ERROR_MSG)
#   7%|▋         | 35/500 [00:17<03:48,  2.04it/s]/Users/patrik/miniconda3/envs/kmpc/lib/python3.11/site-packages/cvxpy/reductions/solvers/solving_chain.py:245: UserWarning: You are solving a parameterized problem that is not DPP. Because the problem is not DPP, subsequent solves will not be faster than the first one. For more information, see the documentation on Disciplined Parametrized Programming, at https://www.cvxpy.org/tutorial/dpp/index.html
#   warnings.warn(DPP_ERROR_MSG)
#   7%|▋         | 36/500 [00:18<03:26,  2.25it/s]/Users/patrik/miniconda3/envs/kmpc/lib/python3.11/site-packages/cvxpy/reductions/solvers/solving_chain.py:245: UserWarning: You are solving a parameterized problem that is not DPP. Because the problem is not DPP, subsequent solves will not be faster than the first one. For more information, see the documentation on Disciplined Parametrized Programming, at https://www.cvxpy.org/tutorial/dpp/index.html
#   warnings.warn(DPP_ERROR_MSG)
#   7%|▋         | 37/500 [00:18<03:28,  2.22it/s]/Users/patrik/miniconda3/envs/kmpc/lib/python3.11/site-packages/cvxpy/reductions/solvers/solving_chain.py:245: UserWarning: You are solving a parameterized problem that is not DPP. Because the problem is not DPP, subsequent solves will not be faster than the first one. For more information, see the documentation on Disciplined Parametrized Programming, at https://www.cvxpy.org/tutorial/dpp/index.html
#   warnings.warn(DPP_ERROR_MSG)
#   8%|▊         | 38/500 [00:18<03:15,  2.37it/s]/Users/patrik/miniconda3/envs/kmpc/lib/python3.11/site-packages/cvxpy/reductions/solvers/solving_chain.py:245: UserWarning: You are solving a parameterized problem that is not DPP. Because the problem is not DPP, subsequent solves will not be faster than the first one. For more information, see the documentation on Disciplined Parametrized Programming, at https://www.cvxpy.org/tutorial/dpp/index.html
#   warnings.warn(DPP_ERROR_MSG)
#   8%|▊         | 39/500 [00:19<03:41,  2.08it/s]/Users/patrik/miniconda3/envs/kmpc/lib/python3.11/site-packages/cvxpy/reductions/solvers/solving_chain.py:245: UserWarning: You are solving a parameterized problem that is not DPP. Because the problem is not DPP, subsequent solves will not be faster than the first one. For more information, see the documentation on Disciplined Parametrized Programming, at https://www.cvxpy.org/tutorial/dpp/index.html
#   warnings.warn(DPP_ERROR_MSG)
#   8%|▊         | 40/500 [00:19<03:21,  2.28it/s]/Users/patrik/miniconda3/envs/kmpc/lib/python3.11/site-packages/cvxpy/reductions/solvers/solving_chain.py:245: UserWarning: You are solving a parameterized problem that is not DPP. Because the problem is not DPP, subsequent solves will not be faster than the first one. For more information, see the documentation on Disciplined Parametrized Programming, at https://www.cvxpy.org/tutorial/dpp/index.html
#   warnings.warn(DPP_ERROR_MSG)
#   8%|▊         | 41/500 [00:20<03:26,  2.22it/s]/Users/patrik/miniconda3/envs/kmpc/lib/python3.11/site-packages/cvxpy/reductions/solvers/solving_chain.py:245: UserWarning: You are solving a parameterized problem that is not DPP. Because the problem is not DPP, subsequent solves will not be faster than the first one. For more information, see the documentation on Disciplined Parametrized Programming, at https://www.cvxpy.org/tutorial/dpp/index.html
#   warnings.warn(DPP_ERROR_MSG)
#   8%|▊         | 42/500 [00:20<03:41,  2.07it/s]/Users/patrik/miniconda3/envs/kmpc/lib/python3.11/site-packages/cvxpy/reductions/solvers/solving_chain.py:245: UserWarning: You are solving a parameterized problem that is not DPP. Because the problem is not DPP, subsequent solves will not be faster than the first one. For more information, see the documentation on Disciplined Parametrized Programming, at https://www.cvxpy.org/tutorial/dpp/index.html
#   warnings.warn(DPP_ERROR_MSG)
#   9%|▊         | 43/500 [00:21<03:34,  2.13it/s]/Users/patrik/miniconda3/envs/kmpc/lib/python3.11/site-packages/cvxpy/reductions/solvers/solving_chain.py:245: UserWarning: You are solving a parameterized problem that is not DPP. Because the problem is not DPP, subsequent solves will not be faster than the first one. For more information, see the documentation on Disciplined Parametrized Programming, at https://www.cvxpy.org/tutorial/dpp/index.html
#   warnings.warn(DPP_ERROR_MSG)
#   9%|▉         | 44/500 [00:21<03:20,  2.27it/s]/Users/patrik/miniconda3/envs/kmpc/lib/python3.11/site-packages/cvxpy/reductions/solvers/solving_chain.py:245: UserWarning: You are solving a parameterized problem that is not DPP. Because the problem is not DPP, subsequent solves will not be faster than the first one. For more information, see the documentation on Disciplined Parametrized Programming, at https://www.cvxpy.org/tutorial/dpp/index.html
#   warnings.warn(DPP_ERROR_MSG)
#   9%|▉         | 45/500 [00:22<03:30,  2.16it/s]/Users/patrik/miniconda3/envs/kmpc/lib/python3.11/site-packages/cvxpy/reductions/solvers/solving_chain.py:245: UserWarning: You are solving a parameterized problem that is not DPP. Because the problem is not DPP, subsequent solves will not be faster than the first one. For more information, see the documentation on Disciplined Parametrized Programming, at https://www.cvxpy.org/tutorial/dpp/index.html
#   warnings.warn(DPP_ERROR_MSG)
#   9%|▉         | 46/500 [00:22<04:14,  1.79it/s]/Users/patrik/miniconda3/envs/kmpc/lib/python3.11/site-packages/cvxpy/reductions/solvers/solving_chain.py:245: UserWarning: You are solving a parameterized problem that is not DPP. Because the problem is not DPP, subsequent solves will not be faster than the first one. For more information, see the documentation on Disciplined Parametrized Programming, at https://www.cvxpy.org/tutorial/dpp/index.html
#   warnings.warn(DPP_ERROR_MSG)
#   9%|▉         | 47/500 [00:23<03:54,  1.93it/s]/Users/patrik/miniconda3/envs/kmpc/lib/python3.11/site-packages/cvxpy/reductions/solvers/solving_chain.py:245: UserWarning: You are solving a parameterized problem that is not DPP. Because the problem is not DPP, subsequent solves will not be faster than the first one. For more information, see the documentation on Disciplined Parametrized Programming, at https://www.cvxpy.org/tutorial/dpp/index.html
#   warnings.warn(DPP_ERROR_MSG)
#  10%|▉         | 48/500 [00:24<05:47,  1.30it/s]/Users/patrik/miniconda3/envs/kmpc/lib/python3.11/site-packages/cvxpy/reductions/solvers/solving_chain.py:245: UserWarning: You are solving a parameterized problem that is not DPP. Because the problem is not DPP, subsequent solves will not be faster than the first one. For more information, see the documentation on Disciplined Parametrized Programming, at https://www.cvxpy.org/tutorial/dpp/index.html
#   warnings.warn(DPP_ERROR_MSG)
#  10%|▉         | 49/500 [00:25<06:28,  1.16it/s]/Users/patrik/miniconda3/envs/kmpc/lib/python3.11/site-packages/cvxpy/reductions/solvers/solving_chain.py:245: UserWarning: You are solving a parameterized problem that is not DPP. Because the problem is not DPP, subsequent solves will not be faster than the first one. For more information, see the documentation on Disciplined Parametrized Programming, at https://www.cvxpy.org/tutorial/dpp/index.html
#   warnings.warn(DPP_ERROR_MSG)
#  10%|█         | 50/500 [00:26<05:32,  1.35it/s]/Users/patrik/miniconda3/envs/kmpc/lib/python3.11/site-packages/cvxpy/reductions/solvers/solving_chain.py:245: UserWarning: You are solving a parameterized problem that is not DPP. Because the problem is not DPP, subsequent solves will not be faster than the first one. For more information, see the documentation on Disciplined Parametrized Programming, at https://www.cvxpy.org/tutorial/dpp/index.html
#   warnings.warn(DPP_ERROR_MSG)
#  10%|█         | 51/500 [00:26<04:58,  1.50it/s]/Users/patrik/miniconda3/envs/kmpc/lib/python3.11/site-packages/cvxpy/reductions/solvers/solving_chain.py:245: UserWarning: You are solving a parameterized problem that is not DPP. Because the problem is not DPP, subsequent solves will not be faster than the first one. For more information, see the documentation on Disciplined Parametrized Programming, at https://www.cvxpy.org/tutorial/dpp/index.html
#   warnings.warn(DPP_ERROR_MSG)
#  10%|█         | 52/500 [00:27<04:21,  1.71it/s]/Users/patrik/miniconda3/envs/kmpc/lib/python3.11/site-packages/cvxpy/reductions/solvers/solving_chain.py:245: UserWarning: You are solving a parameterized problem that is not DPP. Because the problem is not DPP, subsequent solves will not be faster than the first one. For more information, see the documentation on Disciplined Parametrized Programming, at https://www.cvxpy.org/tutorial/dpp/index.html
#   warnings.warn(DPP_ERROR_MSG)
#  11%|█         | 53/500 [00:27<04:20,  1.72it/s]/Users/patrik/miniconda3/envs/kmpc/lib/python3.11/site-packages/cvxpy/reductions/solvers/solving_chain.py:245: UserWarning: You are solving a parameterized problem that is not DPP. Because the problem is not DPP, subsequent solves will not be faster than the first one. For more information, see the documentation on Disciplined Parametrized Programming, at https://www.cvxpy.org/tutorial/dpp/index.html
#   warnings.warn(DPP_ERROR_MSG)
#  11%|█         | 54/500 [00:28<03:55,  1.89it/s]/Users/patrik/miniconda3/envs/kmpc/lib/python3.11/site-packages/cvxpy/reductions/solvers/solving_chain.py:245: UserWarning: You are solving a parameterized problem that is not DPP. Because the problem is not DPP, subsequent solves will not be faster than the first one. For more information, see the documentation on Disciplined Parametrized Programming, at https://www.cvxpy.org/tutorial/dpp/index.html
#   warnings.warn(DPP_ERROR_MSG)
#  11%|█         | 55/500 [00:28<03:52,  1.91it/s]/Users/patrik/miniconda3/envs/kmpc/lib/python3.11/site-packages/cvxpy/reductions/solvers/solving_chain.py:245: UserWarning: You are solving a parameterized problem that is not DPP. Because the problem is not DPP, subsequent solves will not be faster than the first one. For more information, see the documentation on Disciplined Parametrized Programming, at https://www.cvxpy.org/tutorial/dpp/index.html
#   warnings.warn(DPP_ERROR_MSG)
#  11%|█         | 56/500 [00:29<05:16,  1.40it/s]/Users/patrik/miniconda3/envs/kmpc/lib/python3.11/site-packages/cvxpy/reductions/solvers/solving_chain.py:245: UserWarning: You are solving a parameterized problem that is not DPP. Because the problem is not DPP, subsequent solves will not be faster than the first one. For more information, see the documentation on Disciplined Parametrized Programming, at https://www.cvxpy.org/tutorial/dpp/index.html
#   warnings.warn(DPP_ERROR_MSG)
#  11%|█▏        | 57/500 [00:30<04:51,  1.52it/s]/Users/patrik/miniconda3/envs/kmpc/lib/python3.11/site-packages/cvxpy/reductions/solvers/solving_chain.py:245: UserWarning: You are solving a parameterized problem that is not DPP. Because the problem is not DPP, subsequent solves will not be faster than the first one. For more information, see the documentation on Disciplined Parametrized Programming, at https://www.cvxpy.org/tutorial/dpp/index.html
#   warnings.warn(DPP_ERROR_MSG)
#  12%|█▏        | 58/500 [00:30<04:28,  1.64it/s]/Users/patrik/miniconda3/envs/kmpc/lib/python3.11/site-packages/cvxpy/reductions/solvers/solving_chain.py:245: UserWarning: You are solving a parameterized problem that is not DPP. Because the problem is not DPP, subsequent solves will not be faster than the first one. For more information, see the documentation on Disciplined Parametrized Programming, at https://www.cvxpy.org/tutorial/dpp/index.html
#   warnings.warn(DPP_ERROR_MSG)
#  12%|█▏        | 59/500 [00:31<04:16,  1.72it/s]/Users/patrik/miniconda3/envs/kmpc/lib/python3.11/site-packages/cvxpy/reductions/solvers/solving_chain.py:245: UserWarning: You are solving a parameterized problem that is not DPP. Because the problem is not DPP, subsequent solves will not be faster than the first one. For more information, see the documentation on Disciplined Parametrized Programming, at https://www.cvxpy.org/tutorial/dpp/index.html
#   warnings.warn(DPP_ERROR_MSG)
#  12%|█▏        | 60/500 [00:31<04:07,  1.78it/s]/Users/patrik/miniconda3/envs/kmpc/lib/python3.11/site-packages/cvxpy/reductions/solvers/solving_chain.py:245: UserWarning: You are solving a parameterized problem that is not DPP. Because the problem is not DPP, subsequent solves will not be faster than the first one. For more information, see the documentation on Disciplined Parametrized Programming, at https://www.cvxpy.org/tutorial/dpp/index.html
#   warnings.warn(DPP_ERROR_MSG)
#  12%|█▏        | 61/500 [00:32<03:41,  1.98it/s]/Users/patrik/miniconda3/envs/kmpc/lib/python3.11/site-packages/cvxpy/reductions/solvers/solving_chain.py:245: UserWarning: You are solving a parameterized problem that is not DPP. Because the problem is not DPP, subsequent solves will not be faster than the first one. For more information, see the documentation on Disciplined Parametrized Programming, at https://www.cvxpy.org/tutorial/dpp/index.html
#   warnings.warn(DPP_ERROR_MSG)
#  12%|█▏        | 62/500 [00:32<03:49,  1.91it/s]/Users/patrik/miniconda3/envs/kmpc/lib/python3.11/site-packages/cvxpy/reductions/solvers/solving_chain.py:245: UserWarning: You are solving a parameterized problem that is not DPP. Because the problem is not DPP, subsequent solves will not be faster than the first one. For more information, see the documentation on Disciplined Parametrized Programming, at https://www.cvxpy.org/tutorial/dpp/index.html
#   warnings.warn(DPP_ERROR_MSG)
#  13%|█▎        | 63/500 [00:33<03:29,  2.09it/s]/Users/patrik/miniconda3/envs/kmpc/lib/python3.11/site-packages/cvxpy/reductions/solvers/solving_chain.py:245: UserWarning: You are solving a parameterized problem that is not DPP. Because the problem is not DPP, subsequent solves will not be faster than the first one. For more information, see the documentation on Disciplined Parametrized Programming, at https://www.cvxpy.org/tutorial/dpp/index.html
#   warnings.warn(DPP_ERROR_MSG)
#  13%|█▎        | 64/500 [00:33<03:33,  2.05it/s]/Users/patrik/miniconda3/envs/kmpc/lib/python3.11/site-packages/cvxpy/reductions/solvers/solving_chain.py:245: UserWarning: You are solving a parameterized problem that is not DPP. Because the problem is not DPP, subsequent solves will not be faster than the first one. For more information, see the documentation on Disciplined Parametrized Programming, at https://www.cvxpy.org/tutorial/dpp/index.html
#   warnings.warn(DPP_ERROR_MSG)
#  13%|█▎        | 65/500 [00:34<03:26,  2.11it/s]/Users/patrik/miniconda3/envs/kmpc/lib/python3.11/site-packages/cvxpy/reductions/solvers/solving_chain.py:245: UserWarning: You are solving a parameterized problem that is not DPP. Because the problem is not DPP, subsequent solves will not be faster than the first one. For more information, see the documentation on Disciplined Parametrized Programming, at https://www.cvxpy.org/tutorial/dpp/index.html
#   warnings.warn(DPP_ERROR_MSG)
#  13%|█▎        | 66/500 [00:34<03:26,  2.10it/s]/Users/patrik/miniconda3/envs/kmpc/lib/python3.11/site-packages/cvxpy/reductions/solvers/solving_chain.py:245: UserWarning: You are solving a parameterized problem that is not DPP. Because the problem is not DPP, subsequent solves will not be faster than the first one. For more information, see the documentation on Disciplined Parametrized Programming, at https://www.cvxpy.org/tutorial/dpp/index.html
#   warnings.warn(DPP_ERROR_MSG)
#  13%|█▎        | 67/500 [00:35<03:27,  2.09it/s]/Users/patrik/miniconda3/envs/kmpc/lib/python3.11/site-packages/cvxpy/reductions/solvers/solving_chain.py:245: UserWarning: You are solving a parameterized problem that is not DPP. Because the problem is not DPP, subsequent solves will not be faster than the first one. For more information, see the documentation on Disciplined Parametrized Programming, at https://www.cvxpy.org/tutorial/dpp/index.html
#   warnings.warn(DPP_ERROR_MSG)
#  14%|█▎        | 68/500 [00:35<03:15,  2.21it/s]/Users/patrik/miniconda3/envs/kmpc/lib/python3.11/site-packages/cvxpy/reductions/solvers/solving_chain.py:245: UserWarning: You are solving a parameterized problem that is not DPP. Because the problem is not DPP, subsequent solves will not be faster than the first one. For more information, see the documentation on Disciplined Parametrized Programming, at https://www.cvxpy.org/tutorial/dpp/index.html
#   warnings.warn(DPP_ERROR_MSG)
#  14%|█▍        | 69/500 [00:35<03:01,  2.37it/s]/Users/patrik/miniconda3/envs/kmpc/lib/python3.11/site-packages/cvxpy/reductions/solvers/solving_chain.py:245: UserWarning: You are solving a parameterized problem that is not DPP. Because the problem is not DPP, subsequent solves will not be faster than the first one. For more information, see the documentation on Disciplined Parametrized Programming, at https://www.cvxpy.org/tutorial/dpp/index.html
#   warnings.warn(DPP_ERROR_MSG)
#  14%|█▍        | 70/500 [00:36<03:40,  1.95it/s]/Users/patrik/miniconda3/envs/kmpc/lib/python3.11/site-packages/cvxpy/reductions/solvers/solving_chain.py:245: UserWarning: You are solving a parameterized problem that is not DPP. Because the problem is not DPP, subsequent solves will not be faster than the first one. For more information, see the documentation on Disciplined Parametrized Programming, at https://www.cvxpy.org/tutorial/dpp/index.html
#   warnings.warn(DPP_ERROR_MSG)
#  14%|█▍        | 71/500 [00:36<03:22,  2.12it/s]/Users/patrik/miniconda3/envs/kmpc/lib/python3.11/site-packages/cvxpy/reductions/solvers/solving_chain.py:245: UserWarning: You are solving a parameterized problem that is not DPP. Because the problem is not DPP, subsequent solves will not be faster than the first one. For more information, see the documentation on Disciplined Parametrized Programming, at https://www.cvxpy.org/tutorial/dpp/index.html
#   warnings.warn(DPP_ERROR_MSG)
#  14%|█▍        | 72/500 [00:37<03:08,  2.27it/s]/Users/patrik/miniconda3/envs/kmpc/lib/python3.11/site-packages/cvxpy/reductions/solvers/solving_chain.py:245: UserWarning: You are solving a parameterized problem that is not DPP. Because the problem is not DPP, subsequent solves will not be faster than the first one. For more information, see the documentation on Disciplined Parametrized Programming, at https://www.cvxpy.org/tutorial/dpp/index.html
#   warnings.warn(DPP_ERROR_MSG)
#  15%|█▍        | 73/500 [00:37<03:15,  2.18it/s]/Users/patrik/miniconda3/envs/kmpc/lib/python3.11/site-packages/cvxpy/reductions/solvers/solving_chain.py:245: UserWarning: You are solving a parameterized problem that is not DPP. Because the problem is not DPP, subsequent solves will not be faster than the first one. For more information, see the documentation on Disciplined Parametrized Programming, at https://www.cvxpy.org/tutorial/dpp/index.html
#   warnings.warn(DPP_ERROR_MSG)
#  15%|█▍        | 74/500 [00:38<03:06,  2.29it/s]/Users/patrik/miniconda3/envs/kmpc/lib/python3.11/site-packages/cvxpy/reductions/solvers/solving_chain.py:245: UserWarning: You are solving a parameterized problem that is not DPP. Because the problem is not DPP, subsequent solves will not be faster than the first one. For more information, see the documentation on Disciplined Parametrized Programming, at https://www.cvxpy.org/tutorial/dpp/index.html
#   warnings.warn(DPP_ERROR_MSG)
#  15%|█▌        | 75/500 [00:38<03:01,  2.34it/s]/Users/patrik/miniconda3/envs/kmpc/lib/python3.11/site-packages/cvxpy/reductions/solvers/solving_chain.py:245: UserWarning: You are solving a parameterized problem that is not DPP. Because the problem is not DPP, subsequent solves will not be faster than the first one. For more information, see the documentation on Disciplined Parametrized Programming, at https://www.cvxpy.org/tutorial/dpp/index.html
#   warnings.warn(DPP_ERROR_MSG)
#  15%|█▌        | 76/500 [00:39<03:09,  2.24it/s]/Users/patrik/miniconda3/envs/kmpc/lib/python3.11/site-packages/cvxpy/reductions/solvers/solving_chain.py:245: UserWarning: You are solving a parameterized problem that is not DPP. Because the problem is not DPP, subsequent solves will not be faster than the first one. For more information, see the documentation on Disciplined Parametrized Programming, at https://www.cvxpy.org/tutorial/dpp/index.html
#   warnings.warn(DPP_ERROR_MSG)
#  15%|█▌        | 77/500 [00:39<03:05,  2.28it/s]/Users/patrik/miniconda3/envs/kmpc/lib/python3.11/site-packages/cvxpy/reductions/solvers/solving_chain.py:245: UserWarning: You are solving a parameterized problem that is not DPP. Because the problem is not DPP, subsequent solves will not be faster than the first one. For more information, see the documentation on Disciplined Parametrized Programming, at https://www.cvxpy.org/tutorial/dpp/index.html
#   warnings.warn(DPP_ERROR_MSG)
#  16%|█▌        | 78/500 [00:40<03:13,  2.18it/s]/Users/patrik/miniconda3/envs/kmpc/lib/python3.11/site-packages/cvxpy/reductions/solvers/solving_chain.py:245: UserWarning: You are solving a parameterized problem that is not DPP. Because the problem is not DPP, subsequent solves will not be faster than the first one. For more information, see the documentation on Disciplined Parametrized Programming, at https://www.cvxpy.org/tutorial/dpp/index.html
#   warnings.warn(DPP_ERROR_MSG)
#  16%|█▌        | 79/500 [00:40<03:00,  2.33it/s]/Users/patrik/miniconda3/envs/kmpc/lib/python3.11/site-packages/cvxpy/reductions/solvers/solving_chain.py:245: UserWarning: You are solving a parameterized problem that is not DPP. Because the problem is not DPP, subsequent solves will not be faster than the first one. For more information, see the documentation on Disciplined Parametrized Programming, at https://www.cvxpy.org/tutorial/dpp/index.html
#   warnings.warn(DPP_ERROR_MSG)
#  16%|█▌        | 80/500 [00:40<02:50,  2.46it/s]/Users/patrik/miniconda3/envs/kmpc/lib/python3.11/site-packages/cvxpy/reductions/solvers/solving_chain.py:245: UserWarning: You are solving a parameterized problem that is not DPP. Because the problem is not DPP, subsequent solves will not be faster than the first one. For more information, see the documentation on Disciplined Parametrized Programming, at https://www.cvxpy.org/tutorial/dpp/index.html
#   warnings.warn(DPP_ERROR_MSG)
#  16%|█▌        | 81/500 [00:41<02:58,  2.34it/s]/Users/patrik/miniconda3/envs/kmpc/lib/python3.11/site-packages/cvxpy/reductions/solvers/solving_chain.py:245: UserWarning: You are solving a parameterized problem that is not DPP. Because the problem is not DPP, subsequent solves will not be faster than the first one. For more information, see the documentation on Disciplined Parametrized Programming, at https://www.cvxpy.org/tutorial/dpp/index.html
#   warnings.warn(DPP_ERROR_MSG)
#  16%|█▋        | 82/500 [00:41<02:51,  2.44it/s]/Users/patrik/miniconda3/envs/kmpc/lib/python3.11/site-packages/cvxpy/reductions/solvers/solving_chain.py:245: UserWarning: You are solving a parameterized problem that is not DPP. Because the problem is not DPP, subsequent solves will not be faster than the first one. For more information, see the documentation on Disciplined Parametrized Programming, at https://www.cvxpy.org/tutorial/dpp/index.html
#   warnings.warn(DPP_ERROR_MSG)
#  17%|█▋        | 83/500 [00:42<02:56,  2.36it/s]/Users/patrik/miniconda3/envs/kmpc/lib/python3.11/site-packages/cvxpy/reductions/solvers/solving_chain.py:245: UserWarning: You are solving a parameterized problem that is not DPP. Because the problem is not DPP, subsequent solves will not be faster than the first one. For more information, see the documentation on Disciplined Parametrized Programming, at https://www.cvxpy.org/tutorial/dpp/index.html
#   warnings.warn(DPP_ERROR_MSG)
#  17%|█▋        | 84/500 [00:42<03:17,  2.11it/s]/Users/patrik/miniconda3/envs/kmpc/lib/python3.11/site-packages/cvxpy/reductions/solvers/solving_chain.py:245: UserWarning: You are solving a parameterized problem that is not DPP. Because the problem is not DPP, subsequent solves will not be faster than the first one. For more information, see the documentation on Disciplined Parametrized Programming, at https://www.cvxpy.org/tutorial/dpp/index.html
#   warnings.warn(DPP_ERROR_MSG)
#  17%|█▋        | 85/500 [00:43<03:07,  2.21it/s]/Users/patrik/miniconda3/envs/kmpc/lib/python3.11/site-packages/cvxpy/reductions/solvers/solving_chain.py:245: UserWarning: You are solving a parameterized problem that is not DPP. Because the problem is not DPP, subsequent solves will not be faster than the first one. For more information, see the documentation on Disciplined Parametrized Programming, at https://www.cvxpy.org/tutorial/dpp/index.html
#   warnings.warn(DPP_ERROR_MSG)
#  17%|█▋        | 86/500 [00:43<03:16,  2.11it/s]/Users/patrik/miniconda3/envs/kmpc/lib/python3.11/site-packages/cvxpy/reductions/solvers/solving_chain.py:245: UserWarning: You are solving a parameterized problem that is not DPP. Because the problem is not DPP, subsequent solves will not be faster than the first one. For more information, see the documentation on Disciplined Parametrized Programming, at https://www.cvxpy.org/tutorial/dpp/index.html
#   warnings.warn(DPP_ERROR_MSG)
#  17%|█▋        | 87/500 [00:44<03:17,  2.09it/s]/Users/patrik/miniconda3/envs/kmpc/lib/python3.11/site-packages/cvxpy/reductions/solvers/solving_chain.py:245: UserWarning: You are solving a parameterized problem that is not DPP. Because the problem is not DPP, subsequent solves will not be faster than the first one. For more information, see the documentation on Disciplined Parametrized Programming, at https://www.cvxpy.org/tutorial/dpp/index.html
#   warnings.warn(DPP_ERROR_MSG)
#  18%|█▊        | 88/500 [00:44<03:22,  2.04it/s]/Users/patrik/miniconda3/envs/kmpc/lib/python3.11/site-packages/cvxpy/reductions/solvers/solving_chain.py:245: UserWarning: You are solving a parameterized problem that is not DPP. Because the problem is not DPP, subsequent solves will not be faster than the first one. For more information, see the documentation on Disciplined Parametrized Programming, at https://www.cvxpy.org/tutorial/dpp/index.html
#   warnings.warn(DPP_ERROR_MSG)
#  18%|█▊        | 89/500 [00:45<03:32,  1.93it/s]/Users/patrik/miniconda3/envs/kmpc/lib/python3.11/site-packages/cvxpy/reductions/solvers/solving_chain.py:245: UserWarning: You are solving a parameterized problem that is not DPP. Because the problem is not DPP, subsequent solves will not be faster than the first one. For more information, see the documentation on Disciplined Parametrized Programming, at https://www.cvxpy.org/tutorial/dpp/index.html
#   warnings.warn(DPP_ERROR_MSG)
#  18%|█▊        | 90/500 [00:45<03:12,  2.13it/s]/Users/patrik/miniconda3/envs/kmpc/lib/python3.11/site-packages/cvxpy/reductions/solvers/solving_chain.py:245: UserWarning: You are solving a parameterized problem that is not DPP. Because the problem is not DPP, subsequent solves will not be faster than the first one. For more information, see the documentation on Disciplined Parametrized Programming, at https://www.cvxpy.org/tutorial/dpp/index.html
#   warnings.warn(DPP_ERROR_MSG)
#  18%|█▊        | 91/500 [00:45<02:59,  2.28it/s]/Users/patrik/miniconda3/envs/kmpc/lib/python3.11/site-packages/cvxpy/reductions/solvers/solving_chain.py:245: UserWarning: You are solving a parameterized problem that is not DPP. Because the problem is not DPP, subsequent solves will not be faster than the first one. For more information, see the documentation on Disciplined Parametrized Programming, at https://www.cvxpy.org/tutorial/dpp/index.html
#   warnings.warn(DPP_ERROR_MSG)
#  18%|█▊        | 92/500 [00:46<03:11,  2.13it/s]/Users/patrik/miniconda3/envs/kmpc/lib/python3.11/site-packages/cvxpy/reductions/solvers/solving_chain.py:245: UserWarning: You are solving a parameterized problem that is not DPP. Because the problem is not DPP, subsequent solves will not be faster than the first one. For more information, see the documentation on Disciplined Parametrized Programming, at https://www.cvxpy.org/tutorial/dpp/index.html
#   warnings.warn(DPP_ERROR_MSG)
#  19%|█▊        | 93/500 [00:46<03:08,  2.16it/s]/Users/patrik/miniconda3/envs/kmpc/lib/python3.11/site-packages/cvxpy/reductions/solvers/solving_chain.py:245: UserWarning: You are solving a parameterized problem that is not DPP. Because the problem is not DPP, subsequent solves will not be faster than the first one. For more information, see the documentation on Disciplined Parametrized Programming, at https://www.cvxpy.org/tutorial/dpp/index.html
#   warnings.warn(DPP_ERROR_MSG)
#  19%|█▉        | 94/500 [00:47<02:58,  2.28it/s]/Users/patrik/miniconda3/envs/kmpc/lib/python3.11/site-packages/cvxpy/reductions/solvers/solving_chain.py:245: UserWarning: You are solving a parameterized problem that is not DPP. Because the problem is not DPP, subsequent solves will not be faster than the first one. For more information, see the documentation on Disciplined Parametrized Programming, at https://www.cvxpy.org/tutorial/dpp/index.html
#   warnings.warn(DPP_ERROR_MSG)
#  19%|█▉        | 95/500 [00:47<03:04,  2.19it/s]/Users/patrik/miniconda3/envs/kmpc/lib/python3.11/site-packages/cvxpy/reductions/solvers/solving_chain.py:245: UserWarning: You are solving a parameterized problem that is not DPP. Because the problem is not DPP, subsequent solves will not be faster than the first one. For more information, see the documentation on Disciplined Parametrized Programming, at https://www.cvxpy.org/tutorial/dpp/index.html
#   warnings.warn(DPP_ERROR_MSG)
#  19%|█▉        | 96/500 [00:48<02:56,  2.28it/s]/Users/patrik/miniconda3/envs/kmpc/lib/python3.11/site-packages/cvxpy/reductions/solvers/solving_chain.py:245: UserWarning: You are solving a parameterized problem that is not DPP. Because the problem is not DPP, subsequent solves will not be faster than the first one. For more information, see the documentation on Disciplined Parametrized Programming, at https://www.cvxpy.org/tutorial/dpp/index.html
#   warnings.warn(DPP_ERROR_MSG)
#  19%|█▉        | 97/500 [00:48<02:47,  2.41it/s]/Users/patrik/miniconda3/envs/kmpc/lib/python3.11/site-packages/cvxpy/reductions/solvers/solving_chain.py:245: UserWarning: You are solving a parameterized problem that is not DPP. Because the problem is not DPP, subsequent solves will not be faster than the first one. For more information, see the documentation on Disciplined Parametrized Programming, at https://www.cvxpy.org/tutorial/dpp/index.html
#   warnings.warn(DPP_ERROR_MSG)
#  20%|█▉        | 98/500 [00:48<02:53,  2.32it/s]/Users/patrik/miniconda3/envs/kmpc/lib/python3.11/site-packages/cvxpy/reductions/solvers/solving_chain.py:245: UserWarning: You are solving a parameterized problem that is not DPP. Because the problem is not DPP, subsequent solves will not be faster than the first one. For more information, see the documentation on Disciplined Parametrized Programming, at https://www.cvxpy.org/tutorial/dpp/index.html
#   warnings.warn(DPP_ERROR_MSG)
# ...
#   warnings.warn(DPP_ERROR_MSG)
#  94%|█████████▎| 468/500 [03:33<00:13,  2.32it/s]/Users/patrik/miniconda3/envs/kmpc/lib/python3.11/site-packages/cvxpy/reductions/solvers/solving_chain.py:245: UserWarning: You are solving a parameterized problem that is not DPP. Because the problem is not DPP, subsequent solves will not be faster than the first one. For more information, see the documentation on Disciplined Parametrized Programming, at https://www.cvxpy.org/tutorial/dpp/index.html
#   warnings.warn(DPP_ERROR_MSG)
#  94%|█████████▍| 469/500 [03:33<00:13,  2.32it/s]/Users/patrik/miniconda3/envs/kmpc/lib/python3.11/site-packages/cvxpy/reductions/solvers/solving_chain.py:245: UserWarning: You are solving a parameterized problem that is not DPP. Because the problem is not DPP, subsequent solves will not be faster than the first one. For more information, see the documentation on Disciplined Parametrized Programming, at https://www.cvxpy.org/tutorial/dpp/index.html
#   warnings.warn(DPP_ERROR_MSG)
#  94%|█████████▍| 470/500 [03:34<00:13,  2.20it/s]/Users/patrik/miniconda3/envs/kmpc/lib/python3.11/site-packages/cvxpy/reductions/solvers/solving_chain.py:245: UserWarning: You are solving a parameterized problem that is not DPP. Because the problem is not DPP, subsequent solves will not be faster than the first one. For more information, see the documentation on Disciplined Parametrized Programming, at https://www.cvxpy.org/tutorial/dpp/index.html
#   warnings.warn(DPP_ERROR_MSG)
#  94%|█████████▍| 471/500 [03:34<00:12,  2.35it/s]/Users/patrik/miniconda3/envs/kmpc/lib/python3.11/site-packages/cvxpy/reductions/solvers/solving_chain.py:245: UserWarning: You are solving a parameterized problem that is not DPP. Because the problem is not DPP, subsequent solves will not be faster than the first one. For more information, see the documentation on Disciplined Parametrized Programming, at https://www.cvxpy.org/tutorial/dpp/index.html
#   warnings.warn(DPP_ERROR_MSG)
#  94%|█████████▍| 472/500 [03:35<00:12,  2.20it/s]/Users/patrik/miniconda3/envs/kmpc/lib/python3.11/site-packages/cvxpy/reductions/solvers/solving_chain.py:245: UserWarning: You are solving a parameterized problem that is not DPP. Because the problem is not DPP, subsequent solves will not be faster than the first one. For more information, see the documentation on Disciplined Parametrized Programming, at https://www.cvxpy.org/tutorial/dpp/index.html
#   warnings.warn(DPP_ERROR_MSG)
#  95%|█████████▍| 473/500 [03:35<00:14,  1.92it/s]/Users/patrik/miniconda3/envs/kmpc/lib/python3.11/site-packages/cvxpy/reductions/solvers/solving_chain.py:245: UserWarning: You are solving a parameterized problem that is not DPP. Because the problem is not DPP, subsequent solves will not be faster than the first one. For more information, see the documentation on Disciplined Parametrized Programming, at https://www.cvxpy.org/tutorial/dpp/index.html
#   warnings.warn(DPP_ERROR_MSG)
#  95%|█████████▍| 474/500 [03:36<00:12,  2.10it/s]/Users/patrik/miniconda3/envs/kmpc/lib/python3.11/site-packages/cvxpy/reductions/solvers/solving_chain.py:245: UserWarning: You are solving a parameterized problem that is not DPP. Because the problem is not DPP, subsequent solves will not be faster than the first one. For more information, see the documentation on Disciplined Parametrized Programming, at https://www.cvxpy.org/tutorial/dpp/index.html
#   warnings.warn(DPP_ERROR_MSG)
#  95%|█████████▌| 475/500 [03:36<00:11,  2.23it/s]/Users/patrik/miniconda3/envs/kmpc/lib/python3.11/site-packages/cvxpy/reductions/solvers/solving_chain.py:245: UserWarning: You are solving a parameterized problem that is not DPP. Because the problem is not DPP, subsequent solves will not be faster than the first one. For more information, see the documentation on Disciplined Parametrized Programming, at https://www.cvxpy.org/tutorial/dpp/index.html
#   warnings.warn(DPP_ERROR_MSG)
#  95%|█████████▌| 476/500 [03:37<00:11,  2.09it/s]/Users/patrik/miniconda3/envs/kmpc/lib/python3.11/site-packages/cvxpy/reductions/solvers/solving_chain.py:245: UserWarning: You are solving a parameterized problem that is not DPP. Because the problem is not DPP, subsequent solves will not be faster than the first one. For more information, see the documentation on Disciplined Parametrized Programming, at https://www.cvxpy.org/tutorial/dpp/index.html
#   warnings.warn(DPP_ERROR_MSG)
#  95%|█████████▌| 477/500 [03:37<00:11,  2.02it/s]/Users/patrik/miniconda3/envs/kmpc/lib/python3.11/site-packages/cvxpy/reductions/solvers/solving_chain.py:245: UserWarning: You are solving a parameterized problem that is not DPP. Because the problem is not DPP, subsequent solves will not be faster than the first one. For more information, see the documentation on Disciplined Parametrized Programming, at https://www.cvxpy.org/tutorial/dpp/index.html
#   warnings.warn(DPP_ERROR_MSG)
#  96%|█████████▌| 478/500 [03:38<00:12,  1.72it/s]/Users/patrik/miniconda3/envs/kmpc/lib/python3.11/site-packages/cvxpy/reductions/solvers/solving_chain.py:245: UserWarning: You are solving a parameterized problem that is not DPP. Because the problem is not DPP, subsequent solves will not be faster than the first one. For more information, see the documentation on Disciplined Parametrized Programming, at https://www.cvxpy.org/tutorial/dpp/index.html
#   warnings.warn(DPP_ERROR_MSG)
#  96%|█████████▌| 479/500 [03:38<00:10,  1.95it/s]/Users/patrik/miniconda3/envs/kmpc/lib/python3.11/site-packages/cvxpy/reductions/solvers/solving_chain.py:245: UserWarning: You are solving a parameterized problem that is not DPP. Because the problem is not DPP, subsequent solves will not be faster than the first one. For more information, see the documentation on Disciplined Parametrized Programming, at https://www.cvxpy.org/tutorial/dpp/index.html
#   warnings.warn(DPP_ERROR_MSG)
#  96%|█████████▌| 480/500 [03:39<00:09,  2.06it/s]/Users/patrik/miniconda3/envs/kmpc/lib/python3.11/site-packages/cvxpy/reductions/solvers/solving_chain.py:245: UserWarning: You are solving a parameterized problem that is not DPP. Because the problem is not DPP, subsequent solves will not be faster than the first one. For more information, see the documentation on Disciplined Parametrized Programming, at https://www.cvxpy.org/tutorial/dpp/index.html
#   warnings.warn(DPP_ERROR_MSG)
#  96%|█████████▌| 481/500 [03:39<00:09,  2.00it/s]/Users/patrik/miniconda3/envs/kmpc/lib/python3.11/site-packages/cvxpy/reductions/solvers/solving_chain.py:245: UserWarning: You are solving a parameterized problem that is not DPP. Because the problem is not DPP, subsequent solves will not be faster than the first one. For more information, see the documentation on Disciplined Parametrized Programming, at https://www.cvxpy.org/tutorial/dpp/index.html
#   warnings.warn(DPP_ERROR_MSG)
#  96%|█████████▋| 482/500 [03:40<00:08,  2.11it/s]/Users/patrik/miniconda3/envs/kmpc/lib/python3.11/site-packages/cvxpy/reductions/solvers/solving_chain.py:245: UserWarning: You are solving a parameterized problem that is not DPP. Because the problem is not DPP, subsequent solves will not be faster than the first one. For more information, see the documentation on Disciplined Parametrized Programming, at https://www.cvxpy.org/tutorial/dpp/index.html
#   warnings.warn(DPP_ERROR_MSG)
#  97%|█████████▋| 483/500 [03:40<00:07,  2.19it/s]/Users/patrik/miniconda3/envs/kmpc/lib/python3.11/site-packages/cvxpy/reductions/solvers/solving_chain.py:245: UserWarning: You are solving a parameterized problem that is not DPP. Because the problem is not DPP, subsequent solves will not be faster than the first one. For more information, see the documentation on Disciplined Parametrized Programming, at https://www.cvxpy.org/tutorial/dpp/index.html
#   warnings.warn(DPP_ERROR_MSG)
#  97%|█████████▋| 484/500 [03:41<00:07,  2.09it/s]/Users/patrik/miniconda3/envs/kmpc/lib/python3.11/site-packages/cvxpy/reductions/solvers/solving_chain.py:245: UserWarning: You are solving a parameterized problem that is not DPP. Because the problem is not DPP, subsequent solves will not be faster than the first one. For more information, see the documentation on Disciplined Parametrized Programming, at https://www.cvxpy.org/tutorial/dpp/index.html
#   warnings.warn(DPP_ERROR_MSG)
#  97%|█████████▋| 485/500 [03:41<00:06,  2.21it/s]/Users/patrik/miniconda3/envs/kmpc/lib/python3.11/site-packages/cvxpy/reductions/solvers/solving_chain.py:245: UserWarning: You are solving a parameterized problem that is not DPP. Because the problem is not DPP, subsequent solves will not be faster than the first one. For more information, see the documentation on Disciplined Parametrized Programming, at https://www.cvxpy.org/tutorial/dpp/index.html
#   warnings.warn(DPP_ERROR_MSG)
#  97%|█████████▋| 486/500 [03:41<00:06,  2.27it/s]/Users/patrik/miniconda3/envs/kmpc/lib/python3.11/site-packages/cvxpy/reductions/solvers/solving_chain.py:245: UserWarning: You are solving a parameterized problem that is not DPP. Because the problem is not DPP, subsequent solves will not be faster than the first one. For more information, see the documentation on Disciplined Parametrized Programming, at https://www.cvxpy.org/tutorial/dpp/index.html
#   warnings.warn(DPP_ERROR_MSG)
#  97%|█████████▋| 487/500 [03:42<00:05,  2.17it/s]/Users/patrik/miniconda3/envs/kmpc/lib/python3.11/site-packages/cvxpy/reductions/solvers/solving_chain.py:245: UserWarning: You are solving a parameterized problem that is not DPP. Because the problem is not DPP, subsequent solves will not be faster than the first one. For more information, see the documentation on Disciplined Parametrized Programming, at https://www.cvxpy.org/tutorial/dpp/index.html
#   warnings.warn(DPP_ERROR_MSG)
#  98%|█████████▊| 488/500 [03:42<00:05,  2.28it/s]/Users/patrik/miniconda3/envs/kmpc/lib/python3.11/site-packages/cvxpy/reductions/solvers/solving_chain.py:245: UserWarning: You are solving a parameterized problem that is not DPP. Because the problem is not DPP, subsequent solves will not be faster than the first one. For more information, see the documentation on Disciplined Parametrized Programming, at https://www.cvxpy.org/tutorial/dpp/index.html
#   warnings.warn(DPP_ERROR_MSG)
#  98%|█████████▊| 489/500 [03:43<00:04,  2.21it/s]/Users/patrik/miniconda3/envs/kmpc/lib/python3.11/site-packages/cvxpy/reductions/solvers/solving_chain.py:245: UserWarning: You are solving a parameterized problem that is not DPP. Because the problem is not DPP, subsequent solves will not be faster than the first one. For more information, see the documentation on Disciplined Parametrized Programming, at https://www.cvxpy.org/tutorial/dpp/index.html
#   warnings.warn(DPP_ERROR_MSG)
#  98%|█████████▊| 490/500 [03:43<00:04,  2.13it/s]/Users/patrik/miniconda3/envs/kmpc/lib/python3.11/site-packages/cvxpy/reductions/solvers/solving_chain.py:245: UserWarning: You are solving a parameterized problem that is not DPP. Because the problem is not DPP, subsequent solves will not be faster than the first one. For more information, see the documentation on Disciplined Parametrized Programming, at https://www.cvxpy.org/tutorial/dpp/index.html
#   warnings.warn(DPP_ERROR_MSG)
#  98%|█████████▊| 491/500 [03:44<00:03,  2.32it/s]/Users/patrik/miniconda3/envs/kmpc/lib/python3.11/site-packages/cvxpy/reductions/solvers/solving_chain.py:245: UserWarning: You are solving a parameterized problem that is not DPP. Because the problem is not DPP, subsequent solves will not be faster than the first one. For more information, see the documentation on Disciplined Parametrized Programming, at https://www.cvxpy.org/tutorial/dpp/index.html
#   warnings.warn(DPP_ERROR_MSG)
#  98%|█████████▊| 492/500 [03:44<00:03,  2.24it/s]/Users/patrik/miniconda3/envs/kmpc/lib/python3.11/site-packages/cvxpy/reductions/solvers/solving_chain.py:245: UserWarning: You are solving a parameterized problem that is not DPP. Because the problem is not DPP, subsequent solves will not be faster than the first one. For more information, see the documentation on Disciplined Parametrized Programming, at https://www.cvxpy.org/tutorial/dpp/index.html
#   warnings.warn(DPP_ERROR_MSG)
#  99%|█████████▊| 493/500 [03:44<00:02,  2.36it/s]/Users/patrik/miniconda3/envs/kmpc/lib/python3.11/site-packages/cvxpy/reductions/solvers/solving_chain.py:245: UserWarning: You are solving a parameterized problem that is not DPP. Because the problem is not DPP, subsequent solves will not be faster than the first one. For more information, see the documentation on Disciplined Parametrized Programming, at https://www.cvxpy.org/tutorial/dpp/index.html
#   warnings.warn(DPP_ERROR_MSG)
#  99%|█████████▉| 494/500 [03:45<00:02,  2.46it/s]/Users/patrik/miniconda3/envs/kmpc/lib/python3.11/site-packages/cvxpy/reductions/solvers/solving_chain.py:245: UserWarning: You are solving a parameterized problem that is not DPP. Because the problem is not DPP, subsequent solves will not be faster than the first one. For more information, see the documentation on Disciplined Parametrized Programming, at https://www.cvxpy.org/tutorial/dpp/index.html
#   warnings.warn(DPP_ERROR_MSG)
#  99%|█████████▉| 495/500 [03:45<00:02,  2.18it/s]/Users/patrik/miniconda3/envs/kmpc/lib/python3.11/site-packages/cvxpy/reductions/solvers/solving_chain.py:245: UserWarning: You are solving a parameterized problem that is not DPP. Because the problem is not DPP, subsequent solves will not be faster than the first one. For more information, see the documentation on Disciplined Parametrized Programming, at https://www.cvxpy.org/tutorial/dpp/index.html
#   warnings.warn(DPP_ERROR_MSG)
#  99%|█████████▉| 496/500 [03:46<00:01,  2.31it/s]/Users/patrik/miniconda3/envs/kmpc/lib/python3.11/site-packages/cvxpy/reductions/solvers/solving_chain.py:245: UserWarning: You are solving a parameterized problem that is not DPP. Because the problem is not DPP, subsequent solves will not be faster than the first one. For more information, see the documentation on Disciplined Parametrized Programming, at https://www.cvxpy.org/tutorial/dpp/index.html
#   warnings.warn(DPP_ERROR_MSG)
#  99%|█████████▉| 497/500 [03:46<00:01,  2.43it/s]/Users/patrik/miniconda3/envs/kmpc/lib/python3.11/site-packages/cvxpy/reductions/solvers/solving_chain.py:245: UserWarning: You are solving a parameterized problem that is not DPP. Because the problem is not DPP, subsequent solves will not be faster than the first one. For more information, see the documentation on Disciplined Parametrized Programming, at https://www.cvxpy.org/tutorial/dpp/index.html
#   warnings.warn(DPP_ERROR_MSG)
# 100%|█████████▉| 498/500 [03:47<00:00,  2.18it/s]/Users/patrik/miniconda3/envs/kmpc/lib/python3.11/site-packages/cvxpy/reductions/solvers/solving_chain.py:245: UserWarning: You are solving a parameterized problem that is not DPP. Because the problem is not DPP, subsequent solves will not be faster than the first one. For more information, see the documentation on Disciplined Parametrized Programming, at https://www.cvxpy.org/tutorial/dpp/index.html
#   warnings.warn(DPP_ERROR_MSG)
# 100%|█████████▉| 499/500 [03:47<00:00,  2.31it/s]/Users/patrik/miniconda3/envs/kmpc/lib/python3.11/site-packages/cvxpy/reductions/solvers/solving_chain.py:245: UserWarning: You are solving a parameterized problem that is not DPP. Because the problem is not DPP, subsequent solves will not be faster than the first one. For more information, see the documentation on Disciplined Parametrized Programming, at https://www.cvxpy.org/tutorial/dpp/index.html
#   warnings.warn(DPP_ERROR_MSG)
# 100%|██████████| 500/500 [03:47<00:00,  2.19it/s]
# Total time spent in target estimation: 2.2545 seconds
# Total time spent in MPC solve: 205.8546 seconds

# %%
z_sim[:, k].shape
# Out:
# (32,)

# %%
reference = loaded_setup['reference']
# Compute objective in non-scaled units (like NMPC.py)
Qu = loaded_setup['Qu']
Qy = loaded_setup['Qy']
objective_value = 0.0
state_error_cost = 0.0
control_increment_cost = 0.0
for k in range(sim_time):
    y_ref_k = reference[:, k]
    y_diff = y_sim[:, k] - y_ref_k
    prev_u = u_sim[:, k - 1] if k > 0 else u_sim[:, k]
    u_diff = u_sim[:, k] - prev_u
    y_term = float(y_diff.T @ Qy @ y_diff)
    u_term = float(u_diff.T @ Qu @ u_diff)
    state_error_cost += y_term
    control_increment_cost += u_term
    objective_value += y_term + u_term

print(f"Closed-loop objective function value: {objective_value}")
print(f"  - State tracking term: {state_error_cost}")
print(f"  - Input increment term: {control_increment_cost}")



# Plots saved to figures/ in non-scaled domain (8 states, 4 inputs)
names = ['T1', 'T2', 'T3']
n_steps = sim_time
ys_sim_ns = scaler.inverse_transform(ys_sim.T).T
us_sim_ns = scalerU.inverse_transform(us_sim.T).T
y_pred_ns = scaler.inverse_transform(y_pred.T).T
y_projected = get_y_vector(T_real @ z_sim[:nz,:])
y_projected_ns = scaler.inverse_transform(y_projected).T

fig, axs = plt.subplots(min(8, ny), 1, figsize=(12, 2.5*min(8, ny)), sharex=True)
if min(8, ny) == 1:
    axs = [axs]  # ensure axs is iterable even for 1 plot

for i in range(min(8, ny)):
    ax = axs[i]
    ax.plot(y_sim_descaled[i, :], label=names[i] if i < len(names) else f'y{i}')
    if reference_ns is not None:
        ax.plot(reference_ns[i, :n_steps+1], 'r--', label=f'{names[i]} ref' if i < len(names) else f'y{i} ref')
        ax.plot(ys_sim_ns[i, :n_steps], 'k--', label=f'{names[i]} target')
    ax.plot(y_pred_ns[i, :n_steps], 'g--', label=f'{names[i]} pred')
    ax.plot(y_projected_ns[i, :n_steps], 'b--', label=f'{names[i]} projected')
    ax.set_xlabel('Time step')
    ax.set_ylabel(names[i] if i < len(names) else f'y{i}')
    ax.grid(True)
    if i in (0, 1):
        ax.legend()
    if i == 1:
        ax.set_title('CT: linear MPC with nonlinear CSTR plant (states vs ref)')
plt.tight_layout()


fig_inputs, axs = plt.subplots(3, 1, figsize=(12, 10), sharex=True)
input_names = ['q_c', 'q_h', 'P']
for i in range(3):
    axs[i].plot(u_sim_descaled[i, :], label=input_names[i])
    axs[i].plot(us_sim_ns[i, :], 'r--', label=f"{input_names[i]} ref")
    axs[i].set_ylabel(input_names[i])
    axs[i].grid(True)
    axs[i].legend()
axs[-1].set_xlabel('Time step')
fig_inputs.tight_layout()
#412
#627
#398
# Out:
# Closed-loop objective function value: 3928.5933784843764
#   - State tracking term: 3787.803106388932
#   - Input increment term: 140.7902720954418

# %%
sum(u_sim_descaled[2,:])
# Out:
# np.float64(14350.285617517578)

# %%
sum(sum(z_sim[nz:,:]))
# Out:
# np.float64(-731.7967561620856)

# %%
plt.plot(z_sim[nz:,:].T)
# Out:
# [<matplotlib.lines.Line2D at 0x32f55f050>,
#  <matplotlib.lines.Line2D at 0x32fbf39d0>,
#  <matplotlib.lines.Line2D at 0x32fe81750>]

# %%
z_sim[nz:,-1]
# Out:
# array([-0.21760844, -0.15852647, -0.31805208])

# %%
ys_sim_ns[:,-2]
# Out:
# array([56.29506681, 74.95638521, 56.43439102])
